# %%
#dd= make_tip_labels() #this comes from function 1, dd will be defined here based on output of function 1 for the purpose of demonstration
dd= {'ACCIPITRIFORMES': 'Hieraaetus_weiskei',
 'ANSERIFORMES': 'Anas_eatoni',
 'APODIFORMES': 'Xiphorhynchus_elegans',
 'APTERYGIFORMES': 'Pyrilia_aurantiocephala',
 'BUCEROTIFORMES': 'Penelopides_samarensis',
 'CAPRIMULGIFORMES': 'Caprimulgus_heterurus',
 'CARIAMIFORMES': 'Cariama_cristata',
 'CASUARIIFORMES': 'Casuarius_unappendiculatus',
 'CHARADRIIFORMES': 'Gygis_microrhyncha',
 'CICONIIFORMES': 'Leptoptilos_crumeniferus',
 'COLIIFORMES': 'Urocolius_macrourus',
 'COLUMBIFORMES': 'Phapitreron_brunneiceps',
 'CORACIIFORMES': 'Todiramphus_recurvirostris',
 'CUCULIFORMES': 'Eudynamys_orientalis',
 'EURYPYGIFORMES': 'Chunga_burmeisteri',
 'FALCONIFORMES': 'Caracara_cheriway',
 'GALLIFORMES': 'Dendragapus_fuliginosus',
 'GAVIIFORMES': 'Eudyptes_moseleyi',
 'GRUIFORMES': 'Ducula_subflavescens',
 'MESITORNITHIFORMES': 'Mesitornis_unicolor',
 'MUSOPHAGIFORMES': 'Crinifer_zonurus',
 'OTIDIFORMES': 'Houbaropsis_bengalensis',
 'PASSERIFORMES': 'Cinclodes_olrogi',
 'PELECANIFORMES': 'Threskiornis_bernieri',
 'PHAETHONTIFORMES': 'Phaethon_rubricauda',
 'PHOENICOPTERIFORMES': 'Butorides_virescens',
 'PICIFORMES': 'Ramphastos_swainsonii',
 'PODICIPEDIFORMES': 'Aechmophorus_occidentalis',
 'PROCELLARIIFORMES': 'Thalassarche_carteri',
 'PSITTACIFORMES': 'Amazona_oratrix',
 'PTEROCLIDIFORMES': 'Pterocles_lichtensteinii',
 'RHEIFORMES': 'Rhea_americana',
 'SPHENISCIFORMES': 'Pelecanus_thagus',
 'STRIGIFORMES': 'Otus_siaoensis',
 'STRUTHIONIFORMES': 'Struthio_camelus',
 'SULIFORMES': 'Anhinga_novaehollandiae',
 'TINAMIFORMES': 'Apteryx_mantelli',
 'TROGONIFORMES': 'Trogon_aurantiiventris'}

# %%
# This dummy data set is defined here for demonstration purposes, the original file is 10,000 lines!
dummy_data="""28,Struthio camelus,Struthio_camelus,Paleognathae,Paleognaths,Paleognaths,Ostrich,bow00028,LC,BL3,Struthionidae,Ostriches,2,STRUTHIONIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
37,Rhea americana,Rhea_americana,Paleognathae,Paleognaths,Paleognaths,Greater Rhea,bow00037,NT,BL3,Rheidae,Rheas,3,RHEIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
38,Rhea pennata,Rhea_pennata,Paleognathae,Paleognaths,Paleognaths,Lesser Rhea,bow00038,NT,BL3,Rheidae,Rheas,3,RHEIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
45,Casuarius casuarius,Casuarius_casuarius,Paleognathae,Paleognaths,Paleognaths,Southern Cassowary,bow00045,VU,BL3,Casuariidae,Cassowaries,4,CASUARIIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
46,Casuarius bennetti,Casuarius_bennetti,Paleognathae,Paleognaths,Paleognaths,Dwarf Cassowary,bow00046,NT,BL3,Casuariidae,Cassowaries,4,CASUARIIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
47,Casuarius unappendiculatus,Casuarius_unappendiculatus,Paleognathae,Paleognaths,Paleognaths,Northern Cassowary,bow00047,VU,BL3,Casuariidae,Cassowaries,4,CASUARIIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
48,Dromaius novaehollandiae,Dromaius_novaehollandiae,Paleognathae,Paleognaths,Paleognaths,Emu,bow00048,LC,BL3,Dromaiidae,Emus,5,CASUARIIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
55,Apteryx australis,Apteryx_australis,Paleognathae,Paleognaths,Paleognaths,Southern Brown Kiwi,bow00055,VU,BL3,Apterygidae,Kiwis,6,APTERYGIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
57,Apteryx owenii,Apteryx_owenii,Paleognathae,Paleognaths,Paleognaths,Little Spotted Kiwi,bow00057,NT,BL3,Apterygidae,Kiwis,6,APTERYGIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
58,Apteryx haastii,Apteryx_haastii,Paleognathae,Paleognaths,Paleognaths,Great Spotted Kiwi,bow00058,VU,BL3,Apterygidae,Kiwis,6,APTERYGIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
65,Tinamus tao,Tinamus_tao,Paleognathae,Paleognaths,Paleognaths,Grey Tinamou,bow00065,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
66,Tinamus solitarius,Tinamus_solitarius,Paleognathae,Paleognaths,Paleognaths,Solitary Tinamou,bow00066,NT,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
67,Tinamus osgoodi,Tinamus_osgoodi,Paleognathae,Paleognaths,Paleognaths,Black Tinamou,bow00067,VU,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
68,Tinamus major,Tinamus_major,Paleognathae,Paleognaths,Paleognaths,Great Tinamou,bow00068,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
69,Tinamus guttatus,Tinamus_guttatus,Paleognathae,Paleognaths,Paleognaths,White-throated Tinamou,bow00069,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
70,Nothocercus bonapartei,Nothocercus_bonapartei,Paleognathae,Paleognaths,Paleognaths,Highland Tinamou,bow00070,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
71,Nothocercus julius,Nothocercus_julius,Paleognathae,Paleognaths,Paleognaths,Tawny-breasted Tinamou,bow00071,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
72,Nothocercus nigrocapillus,Nothocercus_nigrocapillus,Paleognathae,Paleognaths,Paleognaths,Hooded Tinamou,bow00072,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
73,Crypturellus berlepschi,Crypturellus_berlepschi,Paleognathae,Paleognaths,Paleognaths,Berlepsch's Tinamou,bow00073,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
74,Crypturellus cinereus,Crypturellus_cinereus,Paleognathae,Paleognaths,Paleognaths,Cinereous Tinamou,bow00074,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
75,Crypturellus soui,Crypturellus_soui,Paleognathae,Paleognaths,Paleognaths,Little Tinamou,bow00075,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
76,Crypturellus ptaritepui,Crypturellus_ptaritepui,Paleognathae,Paleognaths,Paleognaths,Tepui Tinamou,bow00076,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
77,Crypturellus obsoletus,Crypturellus_obsoletus,Paleognathae,Paleognaths,Paleognaths,Brown Tinamou,bow00077,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
78,Crypturellus cinnamomeus,Crypturellus_cinnamomeus,Paleognathae,Paleognaths,Paleognaths,Thicket Tinamou,bow00078,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
80,Crypturellus undulatus,Crypturellus_undulatus,Paleognathae,Paleognaths,Paleognaths,Undulated Tinamou,bow00080,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
81,Crypturellus transfasciatus,Crypturellus_transfasciatus,Paleognathae,Paleognaths,Paleognaths,Pale-browed Tinamou,bow00081,NT,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
82,Crypturellus strigulosus,Crypturellus_strigulosus,Paleognathae,Paleognaths,Paleognaths,Brazilian Tinamou,bow00082,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
83,Crypturellus boucardi,Crypturellus_boucardi,Paleognathae,Paleognaths,Paleognaths,Slaty-breasted Tinamou,bow00083,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
84,Crypturellus kerriae,Crypturellus_kerriae,Paleognathae,Paleognaths,Paleognaths,Choco Tinamou,bow00084,VU,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
85,Crypturellus erythropus,Crypturellus_erythropus,Paleognathae,Paleognaths,Paleognaths,Red-legged Tinamou,bow00085,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
87,Crypturellus duidae,Crypturellus_duidae,Paleognathae,Paleognaths,Paleognaths,Grey-legged Tinamou,bow00087,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
88,Crypturellus noctivagus,Crypturellus_noctivagus,Paleognathae,Paleognaths,Paleognaths,Yellow-legged Tinamou,bow00088,NT,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
89,Crypturellus atrocapillus,Crypturellus_atrocapillus,Paleognathae,Paleognaths,Paleognaths,Black-capped Tinamou,bow00089,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
90,Crypturellus variegatus,Crypturellus_variegatus,Paleognathae,Paleognaths,Paleognaths,Variegated Tinamou,bow00090,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
91,Crypturellus brevirostris,Crypturellus_brevirostris,Paleognathae,Paleognaths,Paleognaths,Rusty Tinamou,bow00091,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
92,Crypturellus bartletti,Crypturellus_bartletti,Paleognathae,Paleognaths,Paleognaths,Bartlett's Tinamou,bow00092,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
93,Crypturellus parvirostris,Crypturellus_parvirostris,Paleognathae,Paleognaths,Paleognaths,Small-billed Tinamou,bow00093,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
94,Crypturellus casiquiare,Crypturellus_casiquiare,Paleognathae,Paleognaths,Paleognaths,Barred Tinamou,bow00094,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
95,Crypturellus tataupa,Crypturellus_tataupa,Paleognathae,Paleognaths,Paleognaths,Tataupa Tinamou,bow00095,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
96,Rhynchotus rufescens,Rhynchotus_rufescens,Paleognathae,Paleognaths,Paleognaths,Red-winged Tinamou,bow00096,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
98,Nothoprocta taczanowskii,Nothoprocta_taczanowskii,Paleognathae,Paleognaths,Paleognaths,Taczanowski's Tinamou,bow00098,VU,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
100,Nothoprocta ornata,Nothoprocta_ornata,Paleognathae,Paleognaths,Paleognaths,Ornate Tinamou,bow00100,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
101,Nothoprocta pentlandii,Nothoprocta_pentlandii,Paleognathae,Paleognaths,Paleognaths,Andean Tinamou,bow00101,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
102,Nothoprocta cinerascens,Nothoprocta_cinerascens,Paleognathae,Paleognaths,Paleognaths,Brushland Tinamou,bow00102,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
103,Nothoprocta perdicaria,Nothoprocta_perdicaria,Paleognathae,Paleognaths,Paleognaths,Chilean Tinamou,bow00103,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
104,Nothoprocta curvirostris,Nothoprocta_curvirostris,Paleognathae,Paleognaths,Paleognaths,Curve-billed Tinamou,bow00104,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
105,Nothura darwinii,Nothura_darwinii,Paleognathae,Paleognaths,Paleognaths,Darwin's Nothura,bow00105,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
106,Nothura chacoensis,Nothura_chacoensis,Paleognathae,Paleognaths,Paleognaths,Chaco Nothura,bow00106,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES
107,Nothura maculosa,Nothura_maculosa,Paleognathae,Paleognaths,Paleognaths,Spotted Nothura,bow00107,LC,BL3,Tinamidae,Tinamous,1,TINAMIFORMES,NONPASSERIFORMES,NONPASSERIFORMES"""

# %% [markdown]
# # Function 3: extracting all non-representative species
#
# ***The following code has been modified to be compatible with dummy_data.***
#
# ***Parts of the real code is marked as comments in the body of the code***
#
# ***The second script shows the full code along with the full output***

# %%
def make_non_occurance(tip_label_dict, filename="BLIOCPhyloMasterTaxPrumJarvis.csv"):
# this function extracts all non-representative species in order to drop those tip labels when working with R
    
    #tip label = list index[2]  order = list index [13]
    
    import csv
    import sys
    
    
    #file_object=open(filename, "r", encoding= "ISO-8859-15")#open the file
    
    #master_phylo=csv.reader(file_object)#read the file line by line 
    
    #next(master_phylo,None)#skipping the header
    
    #output=open("non_occurance_reps.csv", "w")#opening output file
    
    dummy_data_splitted=dummy_data.splitlines() 
    
    for line in dummy_data_splitted: #loop over every line of the master phylogeny file
       
        
        line=line.split(",")
    
        if line[2] not in dd.values(): #if the species is not in the list of representative species, it will be in output
            
            #output.write(line[2]+"\r") #populating otput file with non-representative species 
            #"\r" is used because Rstudio handles line endings with "\r" better than "\n"
            
            print(line[2]+",") #for the purpose of demonstartion of the full ouput
            


make_non_occurance(dd)
# Out:
# Rhea_pennata,
# Casuarius_casuarius,
# Casuarius_bennetti,
# Dromaius_novaehollandiae,
# Apteryx_australis,
# Apteryx_owenii,
# Apteryx_haastii,
# Tinamus_tao,
# Tinamus_solitarius,
# Tinamus_osgoodi,
# Tinamus_major,
# Tinamus_guttatus,
# Nothocercus_bonapartei,
# Nothocercus_julius,
# Nothocercus_nigrocapillus,
# Crypturellus_berlepschi,
# Crypturellus_cinereus,
# Crypturellus_soui,
# Crypturellus_ptaritepui,
# Crypturellus_obsoletus,
# Crypturellus_cinnamomeus,
# Crypturellus_undulatus,
# Crypturellus_transfasciatus,
# Crypturellus_strigulosus,
# Crypturellus_boucardi,
# Crypturellus_kerriae,
# Crypturellus_erythropus,
# Crypturellus_duidae,
# Crypturellus_noctivagus,
# Crypturellus_atrocapillus,
# Crypturellus_variegatus,
# Crypturellus_brevirostris,
# Crypturellus_bartletti,
# Crypturellus_parvirostris,
# Crypturellus_casiquiare,
# Crypturellus_tataupa,
# Rhynchotus_rufescens,
# Nothoprocta_taczanowskii,
# Nothoprocta_ornata,
# Nothoprocta_pentlandii,
# Nothoprocta_cinerascens,
# Nothoprocta_perdicaria,
# Nothoprocta_curvirostris,
# Nothura_darwinii,
# Nothura_chacoensis,
# Nothura_maculosa,

# %% [markdown]
# ***The following function shows the full code and full output of the script:***

# %%
def make_non_occurance(tip_label_dict, filename="BLIOCPhyloMasterTaxPrumJarvis.csv"):
# this function extracts all non-representative species in order to drop those tip labels when working with R
    
    #tip label = list index[2]  order = list index [13]
    
    import csv
    import sys
    
    
    file_object=open(filename, "r", encoding= "ISO-8859-15")#open the file
    
    master_phylo=csv.reader(file_object)#read the file line by line 
    
    next(master_phylo,None)#skipping the header
    
    output=open("non_occurance_reps.csv", "w")#opening output file
    
      
    
    for line in master_phylo: #loop over every line of the master phylogeny file
       
        
       
    
        if line[2] not in dd.values(): #if the species is not in the list of representative species, it will be in output
            
            output.write(line[2]+"\r") #populating otput file with non-representative species 
            #"\r" is used because Rstudio handles line endings with "\r" better than "\n"
            
            print(line[2]+ ",") #for the purpose of demonstartion of the full ouput
            


make_non_occurance(dd)
# Out:
# Rhea_pennata,
# Casuarius_casuarius,
# Casuarius_bennetti,
# Dromaius_novaehollandiae,
# Apteryx_australis,
# Apteryx_owenii,
# Apteryx_haastii,
# Tinamus_tao,
# Tinamus_solitarius,
# Tinamus_osgoodi,
# Tinamus_major,
# Tinamus_guttatus,
# Nothocercus_bonapartei,
# Nothocercus_julius,
# Nothocercus_nigrocapillus,
# Crypturellus_berlepschi,
# Crypturellus_cinereus,
# Crypturellus_soui,
# Crypturellus_ptaritepui,
# Crypturellus_obsoletus,
# Crypturellus_cinnamomeus,
# Crypturellus_undulatus,
# Crypturellus_transfasciatus,
# Crypturellus_strigulosus,
# Crypturellus_boucardi,
# Crypturellus_kerriae,
# Crypturellus_erythropus,
# Crypturellus_duidae,
# Crypturellus_noctivagus,
# Crypturellus_atrocapillus,
# Crypturellus_variegatus,
# Crypturellus_brevirostris,
# Crypturellus_bartletti,
# Crypturellus_parvirostris,
# Crypturellus_casiquiare,
# Crypturellus_tataupa,
# Rhynchotus_rufescens,
# Nothoprocta_taczanowskii,
# Nothoprocta_ornata,
# Nothoprocta_pentlandii,
# Nothoprocta_cinerascens,
# Nothoprocta_perdicaria,
# Nothoprocta_curvirostris,
# Nothura_darwinii,
# Nothura_chacoensis,
# Nothura_maculosa,
# Nothura_minor,
# Nothura_boraquira,
# Taoniscus_nanus,
# Eudromia_elegans,
# Eudromia_formosa,
# Tinamotis_pentlandii,
# Tinamotis_ingoufi,
# Ortalis_vetula,
# Ortalis_cinereiceps,
# Ortalis_garrula,
# Ortalis_ruficauda,
# Ortalis_erythroptera,
# Ortalis_wagleri,
# Ortalis_poliocephala,
# Ortalis_canicollis,
# Ortalis_leucogastra,
# Ortalis_guttata,
# Ortalis_motmot,
# Ortalis_superciliaris,
# Penelope_argyrotis,
# Penelope_barbata,
# Penelope_ortoni,
# Penelope_montagnii,
# Penelope_marail,
# Penelope_superciliaris,
# Penelope_dabbenei,
# Penelope_purpurascens,
# Penelope_perspicax,
# Penelope_albipennis,
# Penelope_jacquacu,
# Penelope_obscura,
# Penelope_pileata,
# Penelope_ochrogaster,
# Penelope_jacucaca,
# Pipile_pipile,
# Pipile_cumanensis,
# Pipile_cujubi,
# Pipile_jacutinga,
# Aburria_aburri,
# Chamaepetes_unicolor,
# Chamaepetes_goudotii,
# Penelopina_nigra,
# Oreophasis_derbianus,
# Nothocrax_urumutum,
# Mitu_tomentosum,
# Mitu_salvini,
# Mitu_tuberosum,
# Mitu_mitu,
# Pauxi_pauxi,
# Pauxi_unicornis,
# Crax_rubra,
# Crax_alberti,
# Crax_daubentoni,
# Crax_alector,
# Crax_globulosa,
# Crax_fasciolata,
# Crax_blumenbachii,
# Alectura_lathami,
# Aepypodius_arfakianus,
# Aepypodius_bruijnii,
# Talegalla_cuvieri,
# Talegalla_fuscirostris,
# Talegalla_jobiensis,
# Macrocephalon_maleo,
# Megapodius_nicobariensis,
# Megapodius_cumingii,
# Megapodius_bernsteinii,
# Megapodius_reinwardt,
# Megapodius_freycinet,
# Megapodius_affinis,
# Megapodius_eremita,
# Megapodius_layardi,
# Megapodius_laperouse,
# Megapodius_pritchardii,
# Eulipoa_wallacei,
# Leipoa_ocellata,
# Lerwa_lerwa,
# Ammoperdix_griseogularis,
# Ammoperdix_heyi,
# Tetraogallus_caucasicus,
# Tetraogallus_caspius,
# Tetraogallus_tibetanus,
# Tetraogallus_altaicus,
# Tetraogallus_himalayensis,
# Tetraophasis_obscurus,
# Tetraophasis_szechenyii,
# Alectoris_barbara,
# Alectoris_melanocephala,
# Alectoris_chukar,
# Alectoris_philbyi,
# Alectoris_magna,
# Alectoris_graeca,
# Alectoris_rufa,
# Francolinus_francolinus,
# Francolinus_pictus,
# Francolinus_pintadeanus,
# Francolinus_pondicerianus,
# Francolinus_gularis,
# Francolinus_coqui,
# Francolinus_albogularis,
# Francolinus_schlegelii,
# Francolinus_lathami,
# Francolinus_sephaena,
# Francolinus_streptophorus,
# Francolinus_finschi,
# Francolinus_africanus,
# Francolinus_levaillantii,
# Francolinus_psilolaemus,
# Francolinus_shelleyi,
# Francolinus_levaillantoides,
# Francolinus_nahani,
# Francolinus_hartlaubi,
# Francolinus_bicalcaratus,
# Francolinus_clappertoni,
# Francolinus_icterorhynchus,
# Francolinus_harwoodi,
# Francolinus_adspersus,
# Francolinus_capensis,
# Francolinus_hildebrandti,
# Francolinus_natalensis,
# Francolinus_ahantensis,
# Francolinus_squamatus,
# Francolinus_griseostriatus,
# Francolinus_leucoscepus,
# Francolinus_rufopictus,
# Francolinus_afer,
# Francolinus_swainsonii,
# Francolinus_erckelii,
# Francolinus_ochropectus,
# Francolinus_castaneicollis,
# Francolinus_nobilis,
# Francolinus_jacksoni,
# Francolinus_camerunensis,
# Francolinus_swierstrai,
# Perdix_perdix,
# Perdix_dauurica,
# Perdix_hodgsoniae,
# Rhizothera_longirostris,
# Margaroperdix_madagascariensis,
# Melanoperdix_niger,
# Coturnix_coturnix,
# Coturnix_japonica,
# Coturnix_pectoralis,
# Coturnix_coromandelica,
# Coturnix_delegorguei,
# Coturnix_ypsilophora,
# Coturnix_chinensis,
# Anurophasis_monorthonyx,
# Perdicula_asiatica,
# Perdicula_argoondah,
# Perdicula_erythrorhyncha,
# Perdicula_manipurensis,
# Xenoperdix_udzungwensis,
# Arborophila_torqueola,
# Arborophila_rufogularis,
# Arborophila_atrogularis,
# Arborophila_crudigularis,
# Arborophila_mandellii,
# Arborophila_brunneopectus,
# Arborophila_rufipectus,
# Arborophila_orientalis,
# Arborophila_javanica,
# Arborophila_hyperythra,
# Arborophila_gingica,
# Arborophila_davidi,
# Arborophila_cambodiana,
# Arborophila_rubrirostris,
# Arborophila_ardens,
# Arborophila_chloropus,
# Arborophila_charltonii,
# Caloperdix_oculeus,
# Haematortyx_sanguiniceps,
# Rollulus_rouloul,
# Ptilopachus_petrosus,
# Bambusicola_fytchii,
# Bambusicola_thoracicus,
# Galloperdix_spadicea,
# Galloperdix_lunulata,
# Galloperdix_bicalcarata,
# Ithaginis_cruentus,
# Tragopan_melanocephalus,
# Tragopan_satyra,
# Tragopan_blythii,
# Tragopan_temminckii,
# Tragopan_caboti,
# Pucrasia_macrolopha,
# Lophophorus_impejanus,
# Lophophorus_sclateri,
# Lophophorus_lhuysii,
# Gallus_gallus,
# Gallus_sonneratii,
# Gallus_lafayetii,
# Gallus_varius,
# Lophura_leucomelanos,
# Lophura_nycthemera,
# Lophura_edwardsi,
# Lophura_swinhoii,
# Lophura_inornata,
# Lophura_erythrophthalma,
# Lophura_ignita,
# Lophura_diardi,
# Lophura_bulweri,
# Crossoptilon_crossoptilon,
# Crossoptilon_mantchuricum,
# Crossoptilon_auritum,
# Catreus_wallichi,
# Syrmaticus_ellioti,
# Syrmaticus_humiae,
# Syrmaticus_mikado,
# Syrmaticus_soemmerringii,
# Syrmaticus_reevesii,
# Phasianus_colchicus,
# Chrysolophus_pictus,
# Chrysolophus_amherstiae,
# Polyplectron_chalcurum,
# Polyplectron_inopinatum,
# Polyplectron_germaini,
# Polyplectron_bicalcaratum,
# Polyplectron_malacense,
# Polyplectron_schleiermacheri,
# Polyplectron_napoleonis,
# Rheinardia_ocellata,
# Argusianus_argus,
# Afropavo_congensis,
# Pavo_cristatus,
# Pavo_muticus,
# Dendragapus_falcipennis,
# Dendragapus_canadensis,
# Dendragapus_obscurus,
# Lagopus_lagopus,
# Lagopus_muta,
# Lagopus_leucura,
# Tetrao_tetrix,
# Tetrao_mlokosiewiczi,
# Tetrao_urogallus,
# Tetrao_parvirostris,
# Bonasa_bonasia,
# Bonasa_sewerzowi,
# Bonasa_umbellus,
# Centrocercus_urophasianus,
# Tympanuchus_phasianellus,
# Tympanuchus_cupido,
# Tympanuchus_pallidicinctus,
# Meleagris_gallopavo,
# Meleagris_ocellata,
# Agelastes_meleagrides,
# Agelastes_niger,
# Numida_meleagris,
# Guttera_plumifera,
# Guttera_pucherani,
# Acryllium_vulturinum,
# Dendrortyx_barbatus,
# Dendrortyx_macroura,
# Dendrortyx_leucophrys,
# Oreortyx_pictus,
# Callipepla_squamata,
# Callipepla_douglasii,
# Callipepla_californica,
# Callipepla_gambelii,
# Philortyx_fasciatus,
# Colinus_virginianus,
# Colinus_nigrogularis,
# Colinus_cristatus,
# Odontophorus_gujanensis,
# Odontophorus_capueira,
# Odontophorus_melanotis,
# Odontophorus_erythrops,
# Odontophorus_atrifrons,
# Odontophorus_hyperythrus,
# Odontophorus_melanonotus,
# Odontophorus_speciosus,
# Odontophorus_dialeucos,
# Odontophorus_strophium,
# Odontophorus_columbianus,
# Odontophorus_leucolaemus,
# Odontophorus_balliviani,
# Odontophorus_stellatus,
# Odontophorus_guttatus,
# Dactylortyx_thoracicus,
# Cyrtonyx_montezumae,
# Cyrtonyx_ocellatus,
# Rhynchortyx_cinctus,
# Anhima_cornuta,
# Chauna_chavaria,
# Chauna_torquata,
# Anseranas_semipalmata,
# Dendrocygna_guttata,
# Dendrocygna_eytoni,
# Dendrocygna_bicolor,
# Dendrocygna_arcuata,
# Dendrocygna_javanica,
# Dendrocygna_viduata,
# Dendrocygna_arborea,
# Dendrocygna_autumnalis,
# Thalassornis_leuconotus,
# Nomonyx_dominicus,
# Oxyura_jamaicensis,
# Oxyura_leucocephala,
# Oxyura_maccoa,
# Oxyura_vittata,
# Oxyura_australis,
# Biziura_lobata,
# Heteronetta_atricapilla,
# Stictonetta_naevosa,
# Cygnus_olor,
# Cygnus_atratus,
# Cygnus_melancoryphus,
# Cygnus_cygnus,
# Cygnus_buccinator,
# Cygnus_columbianus,
# Coscoroba_coscoroba,
# Anser_cygnoides,
# Anser_brachyrhynchus,
# Anser_fabalis,
# Anser_albifrons,
# Anser_erythropus,
# Anser_anser,
# Anser_indicus,
# Chen_caerulescens,
# Chen_rossii,
# Chen_canagica,
# Branta_sandvicensis,
# Branta_canadensis,
# Branta_leucopsis,
# Branta_bernicla,
# Branta_ruficollis,
# Cereopsis_novaehollandiae,
# Plectropterus_gambensis,
# Sarkidiornis_melanotos,
# Tadorna_ferruginea,
# Tadorna_cana,
# Tadorna_tadornoides,
# Tadorna_variegata,
# Tadorna_tadorna,
# Tadorna_radjah,
# Malacorhynchus_membranaceus,
# Alopochen_aegyptiaca,
# Neochen_jubata,
# Chloephaga_melanoptera,
# Chloephaga_picta,
# Chloephaga_hybrida,
# Chloephaga_poliocephala,
# Chloephaga_rubidiceps,
# Cyanochen_cyanoptera,
# Hymenolaimus_malacorhynchos,
# Merganetta_armata,
# Tachyeres_pteneres,
# Tachyeres_leucocephalus,
# Tachyeres_brachypterus,
# Tachyeres_patachonicus,
# Pteronetta_hartlaubii,
# Cairina_moschata,
# Cairina_scutulata,
# Aix_sponsa,
# Aix_galericulata,
# Lophonetta_specularioides,
# Nettapus_pulchellus,
# Nettapus_coromandelianus,
# Nettapus_auritus,
# Callonetta_leucophrys,
# Chenonetta_jubata,
# Amazonetta_brasiliensis,
# Salvadorina_waigiuensis,
# Speculanas_specularis,
# Anas_capensis,
# Anas_strepera,
# Anas_falcata,
# Anas_penelope,
# Anas_americana,
# Anas_sibilatrix,
# Anas_sparsa,
# Anas_rubripes,
# Anas_platyrhynchos,
# Anas_poecilorhyncha,
# Anas_superciliosa,
# Anas_luzonica,
# Anas_undulata,
# Anas_melleri,
# Anas_discors,
# Anas_cyanoptera,
# Anas_smithii,
# Anas_platalea,
# Anas_rhynchotis,
# Anas_clypeata,
# Anas_bernieri,
# Anas_gibberifrons,
# Anas_castanea,
# Anas_aucklandica,
# Anas_bahamensis,
# Anas_erythrorhyncha,
# Anas_flavirostris,
# Anas_acuta,
# Anas_georgica,
# Anas_querquedula,
# Anas_formosa,
# Anas_crecca,
# Anas_versicolor,
# Anas_hottentota,
# Marmaronetta_angustirostris,
# Netta_rufina,
# Netta_peposaca,
# Netta_erythrophthalma,
# Aythya_ferina,
# Aythya_valisineria,
# Aythya_americana,
# Aythya_collaris,
# Aythya_nyroca,
# Aythya_innotata,
# Aythya_baeri,
# Aythya_australis,
# Aythya_fuligula,
# Aythya_novaeseelandiae,
# Aythya_marila,
# Aythya_affinis,
# Somateria_mollissima,
# Somateria_spectabilis,
# Somateria_fischeri,
# Polysticta_stelleri,
# Histrionicus_histrionicus,
# Clangula_hyemalis,
# Melanitta_nigra,
# Melanitta_perspicillata,
# Melanitta_fusca,
# Bucephala_clangula,
# Bucephala_islandica,
# Bucephala_albeola,
# Mergellus_albellus,
# Lophodytes_cucullatus,
# Mergus_octosetaceus,
# Mergus_serrator,
# Mergus_squamatus,
# Mergus_merganser,
# Turnix_sylvaticus,
# Turnix_maculosus,
# Turnix_hottentottus,
# Turnix_tanki,
# Turnix_ocellatus,
# Turnix_suscitator,
# Turnix_nigricollis,
# Turnix_melanogaster,
# Turnix_castanotus,
# Turnix_olivii,
# Turnix_varius,
# Turnix_worcesteri,
# Turnix_everetti,
# Turnix_pyrrhothorax,
# Turnix_velox,
# Ortyxelos_meiffrenii,
# Indicator_maculatus,
# Indicator_variegatus,
# Indicator_indicator,
# Indicator_archipelagicus,
# Indicator_minor,
# Indicator_conirostris,
# Indicator_willcocksi,
# Indicator_exilis,
# Indicator_pumilio,
# Indicator_meliphilus,
# Indicator_xanthonotus,
# Melichneutes_robustus,
# Melignomon_eisentrauti,
# Melignomon_zenkeri,
# Prodotiscus_insignis,
# Prodotiscus_zambesiae,
# Prodotiscus_regulus,
# Jynx_torquilla,
# Jynx_ruficollis,
# Picumnus_innominatus,
# Picumnus_aurifrons,
# Picumnus_pumilus,
# Picumnus_lafresnayi,
# Picumnus_exilis,
# Picumnus_fuscus,
# Picumnus_sclateri,
# Picumnus_squamulatus,
# Picumnus_spilogaster,
# Picumnus_minutissimus,
# Picumnus_pygmaeus,
# Picumnus_steindachneri,
# Picumnus_varzeae,
# Picumnus_dorbignyanus,
# Picumnus_temminckii,
# Picumnus_albosquamatus,
# Picumnus_cirratus,
# Picumnus_rufiventris,
# Picumnus_fulvescens,
# Picumnus_limae,
# Picumnus_nebulosus,
# Picumnus_castelnau,
# Picumnus_subtilis,
# Picumnus_olivaceus,
# Picumnus_granadensis,
# Picumnus_cinnamomeus,
# Sasia_africana,
# Sasia_abnormis,
# Sasia_ochracea,
# Nesoctites_micromegas,
# Melanerpes_candidus,
# Melanerpes_lewis,
# Melanerpes_herminieri,
# Melanerpes_portoricensis,
# Melanerpes_erythrocephalus,
# Melanerpes_formicivorus,
# Melanerpes_pucherani,
# Melanerpes_chrysauchen,
# Melanerpes_cruentatus,
# Melanerpes_flavifrons,
# Melanerpes_cactorum,
# Melanerpes_striatus,
# Melanerpes_radiolatus,
# Melanerpes_chrysogenys,
# Melanerpes_hypopolius,
# Melanerpes_pygmaeus,
# Melanerpes_rubricapillus,
# Melanerpes_uropygialis,
# Melanerpes_carolinus,
# Melanerpes_superciliaris,
# Melanerpes_aurifrons,
# Melanerpes_hoffmannii,
# Sphyrapicus_varius,
# Sphyrapicus_nuchalis,
# Sphyrapicus_ruber,
# Sphyrapicus_thyroideus,
# Xiphidiopicus_percussus,
# Campethera_punctuligera,
# Campethera_nubica,
# Campethera_bennettii,
# Campethera_abingoni,
# Campethera_mombassica,
# Campethera_notata,
# Campethera_maculosa,
# Campethera_cailliautii,
# Campethera_tullbergi,
# Campethera_nivosa,
# Campethera_caroli,
# Geocolaptes_olivaceus,
# Dendropicos_elachus,
# Dendropicos_poecilolaemus,
# Dendropicos_abyssinicus,
# Dendropicos_fuscescens,
# Dendropicos_gabonensis,
# Dendropicos_stierlingi,
# Thripias_namaquus,
# Thripias_pyrrhogaster,
# Thripias_xantholophus,
# Mesopicos_elliotii,
# Mesopicos_goertae,
# Dendropicos_spodocephalus,
# Mesopicos_griseocephalus,
# Dendrocopos_obsoletus,
# Dendrocopos_temminckii,
# Dendrocopos_maculatus,
# Dendrocopos_moluccensis,
# Dendrocopos_canicapillus,
# Dendrocopos_kizuki,
# Dendrocopos_minor,
# Dendrocopos_auriceps,
# Dendrocopos_macei,
# Dendrocopos_atratus,
# Dendrocopos_mahrattensis,
# Dendrocopos_dorae,
# Dendrocopos_hyperythrus,
# Dendrocopos_cathpharius,
# Dendrocopos_darjellensis,
# Dendrocopos_medius,
# Dendrocopos_leucotos,
# Dendrocopos_major,
# Dendrocopos_syriacus,
# Dendrocopos_leucopterus,
# Dendrocopos_assimilis,
# Dendrocopos_himalayensis,
# Veniliornis_lignarius,
# Veniliornis_mixtus,
# Picoides_nuttallii,
# Picoides_scalaris,
# Picoides_pubescens,
# Picoides_borealis,
# Picoides_stricklandi,
# Picoides_villosus,
# Picoides_albolarvatus,
# Picoides_tridactylus,
# Picoides_dorsalis,
# Picoides_arcticus,
# Veniliornis_callonotus,
# Veniliornis_dignus,
# Veniliornis_nigriceps,
# Picoides_fumigatus,
# Veniliornis_passerinus,
# Veniliornis_frontalis,
# Veniliornis_spilogaster,
# Veniliornis_sanguineus,
# Veniliornis_kirkii,
# Veniliornis_chocoensis,
# Veniliornis_cassini,
# Veniliornis_affinis,
# Veniliornis_maculifrons,
# Piculus_simplex,
# Piculus_callopterus,
# Piculus_litae,
# Piculus_leucolaemus,
# Piculus_flavigula,
# Piculus_chrysochloros,
# Piculus_aurulentus,
# Colaptes_auricularis,
# Colaptes_rubiginosus,
# Colaptes_rivolii,
# Colaptes_atricollis,
# Colaptes_punctigula,
# Colaptes_melanochloros,
# Colaptes_auratus,
# Colaptes_chrysoides,
# Colaptes_fernandinae,
# Colaptes_pitius,
# Colaptes_rupicola,
# Colaptes_campestris,
# Celeus_brachyurus,
# Celeus_loricatus,
# Celeus_grammicus,
# Celeus_undatus,
# Celeus_castaneus,
# Celeus_elegans,
# Celeus_lugubris,
# Celeus_flavescens,
# Celeus_flavus,
# Celeus_spectabilis,
# Celeus_torquatus,
# Dryocopus_galeatus,
# Dryocopus_pileatus,
# Dryocopus_lineatus,
# Dryocopus_schulzi,
# Dryocopus_javensis,
# Dryocopus_hodgei,
# Dryocopus_martius,
# Campephilus_pollens,
# Campephilus_haematogaster,
# Campephilus_rubricollis,
# Campephilus_robustus,
# Campephilus_guatemalensis,
# Campephilus_melanoleucos,
# Campephilus_gayaquilensis,
# Campephilus_leucopogon,
# Campephilus_magellanicus,
# Campephilus_imperialis,
# Campephilus_principalis,
# Picus_mineaceus,
# Picus_chlorolophus,
# Picus_puniceus,
# Picus_flavinucha,
# Picus_mentalis,
# Picus_viridanus,
# Picus_vittatus,
# Picus_xanthopygaeus,
# Picus_squamatus,
# Picus_awokera,
# Picus_viridis,
# Picus_rabieri,
# Picus_erythropygius,
# Picus_canus,
# Dinopium_rafflesii,
# Dinopium_shorii,
# Dinopium_javanense,
# Dinopium_benghalense,
# Chrysocolaptes_lucidus,
# Chrysocolaptes_festivus,
# Gecinulus_grantia,
# Gecinulus_viridis,
# Dendrocopos_noguchii,
# Blythipicus_rubiginosus,
# Blythipicus_pyrrhotis,
# Reinwardtipicus_validus,
# Meiglyptes_tristis,
# Meiglyptes_jugularis,
# Meiglyptes_tukki,
# Hemicircus_concretus,
# Hemicircus_canente,
# Mulleripicus_fulvus,
# Mulleripicus_funebris,
# Mulleripicus_pulverulentus,
# Psilopogon_pyrolophus,
# Megalaima_virens,
# Megalaima_lagrandieri,
# Megalaima_zeylanica,
# Megalaima_lineata,
# Megalaima_viridis,
# Megalaima_faiostricta,
# Megalaima_corvina,
# Megalaima_chrysopogon,
# Megalaima_rafflesii,
# Megalaima_mystacophanos,
# Megalaima_javensis,
# Megalaima_flavifrons,
# Megalaima_franklinii,
# Megalaima_oorti,
# Megalaima_asiatica,
# Megalaima_monticola,
# Megalaima_incognita,
# Megalaima_henricii,
# Megalaima_armillaris,
# Megalaima_pulcherrima,
# Megalaima_australis,
# Megalaima_eximia,
# Megalaima_rubricapillus,
# Megalaima_haemacephala,
# Calorhamphus_fuliginosus,
# Gymnobucco_calvus,
# Gymnobucco_peli,
# Gymnobucco_sladeni,
# Gymnobucco_bonapartei,
# Stactolaema_leucotis,
# Stactolaema_anchietae,
# Stactolaema_whytii,
# Stactolaema_olivacea,
# Pogoniulus_scolopaceus,
# Pogoniulus_coryphaeus,
# Pogoniulus_leucomystax,
# Pogoniulus_simplex,
# Pogoniulus_atroflavus,
# Pogoniulus_subsulphureus,
# Pogoniulus_bilineatus,
# Pogoniulus_chrysoconus,
# Pogoniulus_pusillus,
# Buccanodon_duchaillui,
# Tricholaema_hirsuta,
# Tricholaema_diademata,
# Tricholaema_frontata,
# Tricholaema_leucomelas,
# Tricholaema_lacrymosa,
# Tricholaema_melanocephala,
# Lybius_undatus,
# Lybius_vieilloti,
# Lybius_leucocephalus,
# Lybius_chaplini,
# Lybius_rubrifacies,
# Lybius_guifsobalito,
# Lybius_torquatus,
# Lybius_melanopterus,
# Lybius_minor,
# Lybius_bidentatus,
# Lybius_dubius,
# Lybius_rolleti,
# Trachyphonus_purpuratus,
# Trachyphonus_vaillantii,
# Trachyphonus_margaritatus,
# Trachyphonus_erythrocephalus,
# Trachyphonus_darnaudii,
# Capito_aurovirens,
# Capito_maculicoronatus,
# Capito_squamatus,
# Capito_hypoleucus,
# Capito_dayi,
# Capito_quinticolor,
# Capito_niger,
# Capito_brunneipectus,
# Eubucco_richardsoni,
# Eubucco_bourcierii,
# Eubucco_tucinkae,
# Eubucco_versicolor,
# Semnornis_frantzii,
# Semnornis_ramphastinus,
# Aulacorhynchus_prasinus,
# Aulacorhynchus_sulcatus,
# Aulacorhynchus_derbianus,
# Aulacorhynchus_haematopygus,
# Aulacorhynchus_huallagae,
# Aulacorhynchus_coeruleicinctis,
# Pteroglossus_inscriptus,
# Pteroglossus_viridis,
# Pteroglossus_bitorquatus,
# Pteroglossus_azara,
# Pteroglossus_castanotis,
# Pteroglossus_aracari,
# Pteroglossus_torquatus,
# Pteroglossus_frantzii,
# Pteroglossus_pluricinctus,
# Pteroglossus_beauharnaesii,
# Pteroglossus_bailloni,
# Andigena_laminirostris,
# Andigena_hypoglauca,
# Andigena_cucullata,
# Andigena_nigrirostris,
# Selenidera_spectabilis,
# Selenidera_reinwardtii,
# Selenidera_nattereri,
# Selenidera_piperivora,
# Selenidera_maculirostris,
# Selenidera_gouldii,
# Ramphastos_sulfuratus,
# Ramphastos_brevis,
# Ramphastos_vitellinus,
# Ramphastos_dicolorus,
# Ramphastos_ambiguus,
# Ramphastos_tucanus,
# Ramphastos_toco,
# Galbalcyrhynchus_leucotis,
# Galbalcyrhynchus_purusianus,
# Brachygalba_salmoni,
# Brachygalba_goeringi,
# Brachygalba_lugubris,
# Brachygalba_albogularis,
# Jacamaralcyon_tridactyla,
# Galbula_albirostris,
# Galbula_cyanicollis,
# Galbula_ruficauda,
# Galbula_galbula,
# Galbula_pastazae,
# Galbula_tombacea,
# Galbula_cyanescens,
# Galbula_chalcothorax,
# Galbula_leucogastra,
# Galbula_dea,
# Jacamerops_aureus,
# Notharchus_macrorhynchos,
# Notharchus_swainsoni,
# Notharchus_pectoralis,
# Notharchus_ordii,
# Notharchus_tectus,
# Bucco_macrodactylus,
# Bucco_tamatia,
# Bucco_noanamae,
# Bucco_capensis,
# Nystalus_radiatus,
# Nystalus_chacuru,
# Nystalus_striolatus,
# Nystalus_maculatus,
# Hypnelus_ruficollis,
# Malacoptila_fusca,
# Malacoptila_semicincta,
# Malacoptila_striata,
# Malacoptila_fulvogularis,
# Malacoptila_rufa,
# Malacoptila_panamensis,
# Malacoptila_mystacalis,
# Micromonacha_lanceolata,
# Nonnula_rubecula,
# Nonnula_sclateri,
# Nonnula_brunnea,
# Nonnula_frontalis,
# Nonnula_ruficapilla,
# Nonnula_amaurocephala,
# Hapaloptila_castanea,
# Monasa_atra,
# Monasa_nigrifrons,
# Monasa_morphoeus,
# Monasa_flavirostris,
# Chelidoptera_tenebrosa,
# Tropicranus_albocristatus,
# Tockus_hartlaubi,
# Tockus_camurus,
# Tockus_monteiri,
# Tockus_erythrorhynchus,
# Tockus_flavirostris,
# Tockus_leucomelas,
# Tockus_deckeni,
# Tockus_alboterminatus,
# Tockus_bradfieldi,
# Tockus_fasciatus,
# Tockus_hemprichii,
# Tockus_nasutus,
# Tockus_pallidirostris,
# Ocyceros_griseus,
# Ocyceros_gingalensis,
# Ocyceros_birostris,
# Anthracoceros_coronatus,
# Anthracoceros_albirostris,
# Anthracoceros_malayanus,
# Anthracoceros_marchei,
# Anthracoceros_montani,
# Buceros_rhinoceros,
# Buceros_bicornis,
# Buceros_hydrocorax,
# Rhinoplax_vigil,
# Anorrhinus_tickelli,
# Anorrhinus_austeni,
# Anorrhinus_galeritus,
# Penelopides_affinis,
# Penelopides_manillae,
# Penelopides_mindorensis,
# Penelopides_panini,
# Penelopides_exarhatus,
# Aceros_comatus,
# Aceros_nipalensis,
# Aceros_corrugatus,
# Aceros_waldeni,
# Aceros_leucocephalus,
# Aceros_cassidix,
# Aceros_undulatus,
# Aceros_narcondami,
# Aceros_everetti,
# Aceros_subruficollis,
# Aceros_plicatus,
# Bycanistes_bucinator,
# Bycanistes_fistulator,
# Bycanistes_brevis,
# Bycanistes_subcylindricus,
# Bycanistes_cylindricus,
# Ceratogymna_atrata,
# Ceratogymna_elata,
# Bucorvus_abyssinicus,
# Bucorvus_cafer,
# Upupa_epops,
# Phoeniculus_purpureus,
# Phoeniculus_damarensis,
# Phoeniculus_somaliensis,
# Phoeniculus_bollei,
# Phoeniculus_castaneiceps,
# Rhinopomastus_aterrimus,
# Rhinopomastus_cyanomelas,
# Rhinopomastus_minor,
# Apaloderma_narina,
# Apaloderma_aequatoriale,
# Apaloderma_vittatum,
# Pharomachrus_mocinno,
# Pharomachrus_antisianus,
# Pharomachrus_fulgidus,
# Pharomachrus_auriceps,
# Pharomachrus_pavoninus,
# Euptilotis_neoxenus,
# Priotelus_temnurus,
# Priotelus_roseigaster,
# Trogon_massena,
# Trogon_melanurus,
# Trogon_clathratus,
# Trogon_comptus,
# Trogon_bairdii,
# Trogon_viridis,
# Trogon_citreolus,
# Trogon_melanocephalus,
# Trogon_mexicanus,
# Trogon_elegans,
# Trogon_collaris,
# Trogon_personatus,
# Trogon_rufus,
# Trogon_surrucura,
# Trogon_curucui,
# Trogon_violaceus,
# Apalharpactes_reinwardtii,
# Harpactes_fasciatus,
# Harpactes_kasumba,
# Harpactes_diardii,
# Harpactes_ardens,
# Harpactes_whiteheadi,
# Harpactes_orrhophaeus,
# Harpactes_duvaucelii,
# Harpactes_oreskios,
# Harpactes_erythrocephalus,
# Harpactes_wardi,
# Coracias_garrulus,
# Coracias_abyssinicus,
# Coracias_caudatus,
# Coracias_spatulatus,
# Coracias_naevia,
# Coracias_benghalensis,
# Coracias_temminckii,
# Coracias_cyanogaster,
# Eurystomus_glaucurus,
# Eurystomus_gularis,
# Eurystomus_orientalis,
# Eurystomus_azureus,
# Brachypteracias_leptosomus,
# Brachypteracias_squamiger,
# Atelornis_pittoides,
# Atelornis_crossleyi,
# Uratelornis_chimaera,
# Leptosomus_discolor,
# Hylomanes_momotula,
# Aspatha_gularis,
# Electron_platyrhynchum,
# Electron_carinatum,
# Eumomota_superciliosa,
# Baryphthengus_martii,
# Baryphthengus_ruficapillus,
# Momotus_mexicanus,
# Momotus_momota,
# Momotus_aequatorialis,
# Todus_multicolor,
# Todus_angustirostris,
# Todus_mexicanus,
# Todus_todus,
# Todus_subulatus,
# Alcedo_hercules,
# Alcedo_atthis,
# Alcedo_semitorquata,
# Alcedo_quadribrachys,
# Alcedo_meninting,
# Alcedo_azurea,
# Alcedo_websteri,
# Alcedo_euryzona,
# Alcedo_cyanopectus,
# Alcedo_argentata,
# Alcedo_cristata,
# Alcedo_vintsioides,
# Alcedo_leucogaster,
# Alcedo_coerulescens,
# Alcedo_pusilla,
# Ceyx_lepidus,
# Ceyx_erithaca,
# Ceyx_melanurus,
# Ceyx_fallax,
# Ceyx_madagascariensis,
# Ceyx_pictus,
# Ceyx_lecontei,
# Lacedo_pulchella,
# Dacelo_novaeguineae,
# Dacelo_leachii,
# Dacelo_tyro,
# Dacelo_gaudichaud,
# Clytoceyx_rex,
# Cittura_cyanotis,
# Pelargopsis_amauroptera,
# Pelargopsis_capensis,
# Pelargopsis_melanorhyncha,
# Halcyon_coromanda,
# Halcyon_badia,
# Halcyon_smyrnensis,
# Halcyon_pileata,
# Halcyon_cyanoventris,
# Halcyon_leucocephala,
# Halcyon_senegalensis,
# Halcyon_senegaloides,
# Halcyon_malimbica,
# Halcyon_albiventris,
# Halcyon_chelicuti,
# Todiramphus_nigrocyaneus,
# Todiramphus_winchelli,
# Todiramphus_diops,
# Todiramphus_lazuli,
# Todiramphus_macleayii,
# Todiramphus_albonotatus,
# Todiramphus_leucopygius,
# Todiramphus_farquhari,
# Todiramphus_pyrrhopygius,
# Todiramphus_cinnamominus,
# Todiramphus_funebris,
# Todiramphus_chloris,
# Todiramphus_enigma,
# Todiramphus_saurophaga,
# Todiramphus_australasia,
# Todiramphus_sanctus,
# Todiramphus_veneratus,
# Todiramphus_tutus,
# Todiramphus_godeffroyi,
# Todiramphus_gambieri,
# Caridonax_fulgidus,
# Melidora_macrorrhina,
# Actenoides_bougainvillei,
# Actenoides_concretus,
# Actenoides_lindsayi,
# Actenoides_hombroni,
# Actenoides_monachus,
# Actenoides_princeps,
# Syma_torotoro,
# Syma_megarhyncha,
# Tanysiptera_hydrocharis,
# Tanysiptera_galatea,
# Tanysiptera_ellioti,
# Tanysiptera_riedelii,
# Tanysiptera_carolinae,
# Tanysiptera_nympha,
# Tanysiptera_danae,
# Tanysiptera_sylvia,
# Megaceryle_maxima,
# Megaceryle_lugubris,
# Megaceryle_alcyon,
# Megaceryle_torquata,
# Ceryle_rudis,
# Chloroceryle_amazona,
# Chloroceryle_americana,
# Chloroceryle_inda,
# Chloroceryle_aenea,
# Nyctyornis_amictus,
# Nyctyornis_athertoni,
# Meropogon_forsteni,
# Merops_gularis,
# Merops_muelleri,
# Merops_bulocki,
# Merops_bullockoides,
# Merops_pusillus,
# Merops_variegatus,
# Merops_oreobates,
# Merops_hirundineus,
# Merops_breweri,
# Merops_revoilii,
# Merops_albicollis,
# Merops_orientalis,
# Merops_boehmi,
# Merops_viridis,
# Merops_persicus,
# Merops_superciliosus,
# Merops_philippinus,
# Merops_ornatus,
# Merops_apiaster,
# Merops_leschenaulti,
# Merops_malimbicus,
# Merops_nubicus,
# Colius_striatus,
# Colius_leucocephalus,
# Colius_castanotus,
# Colius_colius,
# Urocolius_indicus,
# Clamator_jacobinus,
# Clamator_levaillantii,
# Clamator_coromandus,
# Clamator_glandarius,
# Pachycoccyx_audeberti,
# Cuculus_crassirostris,
# Cuculus_sparverioides,
# Cuculus_varius,
# Cuculus_vagans,
# Cuculus_fugax,
# Cuculus_solitarius,
# Cuculus_clamosus,
# Cuculus_micropterus,
# Cuculus_canorus,
# Cuculus_gularis,
# Cuculus_saturatus,
# Cuculus_poliocephalus,
# Cuculus_rochii,
# Cuculus_pallidus,
# Cercococcyx_mechowi,
# Cercococcyx_olivinus,
# Cercococcyx_montanus,
# Cacomantis_sonneratii,
# Cacomantis_merulinus,
# Cacomantis_variolosus,
# Cacomantis_castaneiventris,
# Cacomantis_heinrichi,
# Cacomantis_flabelliformis,
# Rhamphomantis_megarhynchus,
# Chrysococcyx_minutillus,
# Chrysococcyx_lucidus,
# Chrysococcyx_basalis,
# Chrysococcyx_ruficollis,
# Chrysococcyx_meyeri,
# Chrysococcyx_maculatus,
# Chrysococcyx_xanthorhynchus,
# Chrysococcyx_osculans,
# Chrysococcyx_flavigularis,
# Chrysococcyx_klaas,
# Chrysococcyx_cupreus,
# Chrysococcyx_caprius,
# Caliechthrus_leucolophus,
# Surniculus_lugubris,
# Microdynamis_parva,
# Eudynamys_scolopaceus,
# Eudynamys_taitensis,
# Scythrops_novaehollandiae,
# Ceuthmochares_aereus,
# Phaenicophaeus_diardi,
# Phaenicophaeus_sumatranus,
# Phaenicophaeus_tristis,
# Phaenicophaeus_viridirostris,
# Phaenicophaeus_leschenaultii,
# Phaenicophaeus_chlorophaeus,
# Phaenicophaeus_javanicus,
# Phaenicophaeus_calyorhynchus,
# Phaenicophaeus_curvirostris,
# Phaenicophaeus_pyrrhocephalus,
# Phaenicophaeus_superciliosus,
# Phaenicophaeus_cumingi,
# Carpococcyx_radiatus,
# Carpococcyx_viridis,
# Carpococcyx_renauldi,
# Coua_gigas,
# Coua_coquereli,
# Coua_serriana,
# Coua_reynaudii,
# Coua_cursor,
# Coua_ruficeps,
# Coua_cristata,
# Coua_verreauxi,
# Coua_caerulea,
# Centropus_milo,
# Centropus_goliath,
# Centropus_violaceus,
# Centropus_menbeki,
# Centropus_ateralbus,
# Centropus_phasianinus,
# Centropus_spilopterus,
# Centropus_bernsteini,
# Centropus_chalybeus,
# Centropus_rectunguis,
# Centropus_steerii,
# Centropus_sinensis,
# Centropus_andamanensis,
# Centropus_nigrorufus,
# Centropus_viridis,
# Centropus_toulou,
# Centropus_grillii,
# Centropus_bengalensis,
# Centropus_chlororhynchus,
# Centropus_leucogaster,
# Centropus_anselli,
# Centropus_monachus,
# Centropus_cupreicaudus,
# Centropus_senegalensis,
# Centropus_superciliosus,
# Centropus_melanops,
# Centropus_celebensis,
# Centropus_unirufus,
# Coccycua_pumila,
# Coccycua_cinerea,
# Coccyzus_erythropthalmus,
# Coccyzus_americanus,
# Coccyzus_euleri,
# Coccyzus_minor,
# Coccyzus_ferrugineus,
# Coccyzus_melacoryphus,
# Coccyzus_lansbergi,
# Coccyzus_pluvialis,
# Coccyzus_rufigularis,
# Piaya_cayana,
# Piaya_melanogaster,
# Coccycua_minuta,
# Coccyzus_merlini,
# Coccyzus_vetula,
# Coccyzus_longirostris,
# Coccyzus_vieilloti,
# Crotophaga_major,
# Crotophaga_ani,
# Crotophaga_sulcirostris,
# Guira_guira,
# Tapera_naevia,
# Morococcyx_erythropygus,
# Dromococcyx_phasianellus,
# Dromococcyx_pavoninus,
# Geococcyx_californianus,
# Geococcyx_velox,
# Neomorphus_geoffroyi,
# Neomorphus_radiolosus,
# Neomorphus_rufipennis,
# Neomorphus_pucheranii,
# Opisthocomus_hoazin,
# Probosciger_aterrimus,
# Calyptorhynchus_baudinii,
# Calyptorhynchus_latirostris,
# Calyptorhynchus_funereus,
# Calyptorhynchus_banksii,
# Calyptorhynchus_lathami,
# Callocephalon_fimbriatum,
# Cacatua_roseicapilla,
# Cacatua_leadbeateri,
# Cacatua_sulphurea,
# Cacatua_galerita,
# Cacatua_ophthalmica,
# Cacatua_moluccensis,
# Cacatua_alba,
# Cacatua_haematuropygia,
# Cacatua_goffiniana,
# Cacatua_sanguinea,
# Cacatua_pastinator,
# Cacatua_tenuirostris,
# Cacatua_ducorpsii,
# Nymphicus_hollandicus,
# Chalcopsitta_atra,
# Chalcopsitta_duivenbodei,
# Chalcopsitta_sintillata,
# Chalcopsitta_cardinalis,
# Eos_histrio,
# Eos_squamata,
# Eos_bornea,
# Eos_reticulata,
# Eos_cyanogenia,
# Eos_semilarvata,
# Pseudeos_fuscata,
# Trichoglossus_ornatus,
# Trichoglossus_haematodus,
# Trichoglossus_euteles,
# Trichoglossus_flavoviridis,
# Trichoglossus_johnstoniae,
# Trichoglossus_rubiginosus,
# Trichoglossus_chlorolepidotus,
# Psitteuteles_versicolor,
# Psitteuteles_iris,
# Psitteuteles_goldiei,
# Lorius_garrulus,
# Lorius_domicella,
# Lorius_lory,
# Lorius_hypoinochrous,
# Lorius_albidinucha,
# Lorius_chlorocercus,
# Phigys_solitarius,
# Vini_australis,
# Vini_kuhlii,
# Vini_stepheni,
# Vini_peruviana,
# Vini_ultramarina,
# Glossopsitta_concinna,
# Glossopsitta_pusilla,
# Glossopsitta_porphyrocephala,
# Charmosyna_palmarum,
# Charmosyna_rubrigularis,
# Charmosyna_meeki,
# Charmosyna_toxopei,
# Charmosyna_multistriata,
# Charmosyna_wilhelminae,
# Charmosyna_rubronotata,
# Charmosyna_placentis,
# Charmosyna_diadema,
# Charmosyna_amabilis,
# Charmosyna_margarethae,
# Charmosyna_pulchella,
# Charmosyna_josefinae,
# Charmosyna_papou,
# Oreopsittacus_arfaki,
# Neopsittacus_musschenbroekii,
# Neopsittacus_pullicauda,
# Nestor_notabilis,
# Nestor_meridionalis,
# Micropsitta_keiensis,
# Micropsitta_geelvinkiana,
# Micropsitta_pusio,
# Micropsitta_meeki,
# Micropsitta_finschii,
# Micropsitta_bruijnii,
# Cyclopsitta_gulielmitertii,
# Cyclopsitta_diophthalma,
# Psittaculirostris_desmarestii,
# Psittaculirostris_edwardsii,
# Psittaculirostris_salvadorii,
# Bolbopsittacus_lunulatus,
# Psittinus_cyanurus,
# Psittacella_brehmii,
# Psittacella_picta,
# Psittacella_modesta,
# Psittacella_madaraszi,
# Geoffroyus_geoffroyi,
# Geoffroyus_simplex,
# Geoffroyus_heteroclitus,
# Prioniturus_montanus,
# Prioniturus_waterstradti,
# Prioniturus_platenae,
# Prioniturus_luconensis,
# Prioniturus_discurus,
# Prioniturus_verticalis,
# Prioniturus_flavicans,
# Prioniturus_platurus,
# Prioniturus_mada,
# Tanygnathus_megalorynchos,
# Tanygnathus_lucionensis,
# Tanygnathus_sumatranus,
# Tanygnathus_gramineus,
# Eclectus_roratus,
# Psittrichas_fulgidus,
# Prosopeia_splendens,
# Prosopeia_personata,
# Prosopeia_tabuensis,
# Alisterus_scapularis,
# Alisterus_amboinensis,
# Alisterus_chloropterus,
# Aprosmictus_jonquillaceus,
# Aprosmictus_erythropterus,
# Polytelis_swainsonii,
# Polytelis_anthopeplus,
# Polytelis_alexandrae,
# Purpureicephalus_spurius,
# Barnardius_zonarius,
# Platycercus_caledonicus,
# Platycercus_elegans,
# Platycercus_venustus,
# Platycercus_adscitus,
# Platycercus_eximius,
# Platycercus_icterotis,
# Northiella_haematogaster,
# Psephotus_haematonotus,
# Psephotus_varius,
# Psephotus_dissimilis,
# Psephotus_chrysopterygius,
# Cyanoramphus_unicolor,
# Cyanoramphus_novaezelandiae,
# Cyanoramphus_auriceps,
# Eunymphicus_cornutus,
# Neopsephotus_bourkii,
# Neophema_chrysostoma,
# Neophema_elegans,
# Neophema_petrophila,
# Neophema_chrysogaster,
# Neophema_pulchella,
# Neophema_splendida,
# Lathamus_discolor,
# Melopsittacus_undulatus,
# Pezoporus_wallicus,
# Pezoporus_occidentalis,
# Strigops_habroptila,
# Coracopsis_vasa,
# Coracopsis_nigra,
# Psittacus_erithacus,
# Poicephalus_robustus,
# Poicephalus_gulielmi,
# Poicephalus_senegalus,
# Poicephalus_crassus,
# Poicephalus_meyeri,
# Poicephalus_flavifrons,
# Poicephalus_rufiventris,
# Poicephalus_cryptoxanthus,
# Poicephalus_rueppellii,
# Agapornis_canus,
# Agapornis_pullarius,
# Agapornis_taranta,
# Agapornis_swindernianus,
# Agapornis_roseicollis,
# Agapornis_fischeri,
# Agapornis_personatus,
# Agapornis_lilianae,
# Agapornis_nigrigenis,
# Loriculus_vernalis,
# Loriculus_beryllinus,
# Loriculus_philippensis,
# Loriculus_galgulus,
# Loriculus_stigmatus,
# Loriculus_amabilis,
# Loriculus_catamene,
# Loriculus_aurantiifrons,
# Loriculus_tener,
# Loriculus_exilis,
# Loriculus_pusillus,
# Loriculus_flosculus,
# Psittacula_eupatria,
# Psittacula_krameri,
# Psittacula_eques,
# Psittacula_himalayana,
# Psittacula_finschii,
# Psittacula_cyanocephala,
# Psittacula_roseata,
# Psittacula_columboides,
# Psittacula_calthropae,
# Psittacula_derbiana,
# Psittacula_alexandri,
# Psittacula_caniceps,
# Psittacula_longicauda,
# Anodorhynchus_hyacinthinus,
# Anodorhynchus_leari,
# Cyanopsitta_spixii,
# Ara_ararauna,
# Ara_glaucogularis,
# Ara_militaris,
# Ara_ambiguus,
# Ara_macao,
# Ara_chloropterus,
# Ara_rubrogenys,
# Ara_severus,
# Orthopsittaca_manilata,
# Primolius_couloni,
# Primolius_maracana,
# Primolius_auricollis,
# Diopsittaca_nobilis,
# Aratinga_acuticaudata,
# Guaruba_guarouba,
# Aratinga_holochlora,
# Aratinga_brevipes,
# Aratinga_rubritorquis,
# Aratinga_wagleri,
# Aratinga_mitrata,
# Aratinga_erythrogenys,
# Aratinga_finschi,
# Aratinga_leucophthalma,
# Aratinga_euops,
# Aratinga_chloroptera,
# Aratinga_solstitialis,
# Aratinga_jandaya,
# Aratinga_auricapillus,
# Aratinga_weddellii,
# Aratinga_nana,
# Aratinga_canicularis,
# Aratinga_aurea,
# Aratinga_pertinax,
# Aratinga_cactorum,
# Nandayus_nenday,
# Leptosittaca_branickii,
# Ognorhynchus_icterotis,
# Rhynchopsitta_pachyrhyncha,
# Rhynchopsitta_terrisi,
# Cyanoliseus_patagonus,
# Pyrrhura_cruentata,
# Pyrrhura_devillei,
# Pyrrhura_frontalis,
# Pyrrhura_lepida,
# Pyrrhura_perlata,
# Pyrrhura_molinae,
# Pyrrhura_picta,
# Pyrrhura_leucotis,
# Pyrrhura_viridicata,
# Pyrrhura_egregia,
# Pyrrhura_melanura,
# Pyrrhura_orcesi,
# Pyrrhura_rupicola,
# Pyrrhura_albipectus,
# Pyrrhura_calliptera,
# Pyrrhura_hoematotis,
# Pyrrhura_rhodocephala,
# Pyrrhura_hoffmanni,
# Enicognathus_ferrugineus,
# Enicognathus_leptorhynchus,
# Myiopsitta_monachus,
# Psilopsiagon_aymara,
# Psilopsiagon_aurifrons,
# Bolborhynchus_lineola,
# Bolborhynchus_orbygnesius,
# Bolborhynchus_ferrugineifrons,
# Forpus_cyanopygius,
# Forpus_passerinus,
# Forpus_xanthopterygius,
# Forpus_conspicillatus,
# Forpus_modestus,
# Forpus_coelestis,
# Forpus_xanthops,
# Brotogeris_tirica,
# Brotogeris_versicolurus,
# Brotogeris_chiriri,
# Brotogeris_pyrrhoptera,
# Brotogeris_jugularis,
# Brotogeris_cyanoptera,
# Brotogeris_chrysoptera,
# Brotogeris_sanctithomae,
# Nannopsittaca_panychlora,
# Nannopsittaca_dachilleae,
# Touit_batavicus,
# Touit_huetii,
# Touit_costaricensis,
# Touit_dilectissimus,
# Touit_purpuratus,
# Touit_melanonotus,
# Touit_surdus,
# Touit_stictopterus,
# Pionites_melanocephalus,
# Pionites_leucogaster,
# Pionopsitta_pileata,
# Pyrilia_haematotis,
# Pyrilia_pulchra,
# Pyrilia_barrabandi,
# Pyrilia_pyrilia,
# Pyrilia_caica,
# Pyrilia_vulturina,
# Hapalopsittaca_melanotis,
# Hapalopsittaca_amazonina,
# Hapalopsittaca_fuertesi,
# Hapalopsittaca_pyrrhops,
# Graydidascalus_brachyurus,
# Pionus_menstruus,
# Pionus_sordidus,
# Pionus_maximiliani,
# Pionus_tumultuosus,
# Pionus_senilis,
# Pionus_chalcopterus,
# Pionus_fuscus,
# Amazona_leucocephala,
# Amazona_collaria,
# Amazona_ventralis,
# Amazona_albifrons,
# Amazona_xantholora,
# Amazona_agilis,
# Amazona_vittata,
# Amazona_tucumana,
# Amazona_pretrei,
# Amazona_viridigenalis,
# Amazona_finschi,
# Amazona_autumnalis,
# Amazona_dufresniana,
# Amazona_rhodocorytha,
# Amazona_brasiliensis,
# Amazona_festiva,
# Alipiopsitta_xanthops,
# Amazona_barbadensis,
# Amazona_aestiva,
# Amazona_ochrocephala,
# Amazona_amazonica,
# Amazona_mercenaria,
# Amazona_farinosa,
# Amazona_kawalli,
# Amazona_vinacea,
# Amazona_versicolor,
# Amazona_arausiaca,
# Amazona_guildingii,
# Amazona_imperialis,
# Deroptyus_accipitrinus,
# Triclaria_malachitacea,
# Cypseloides_niger,
# Cypseloides_lemosi,
# Cypseloides_rothschildi,
# Cypseloides_fumigatus,
# Cypseloides_cherriei,
# Cypseloides_storeri,
# Cypseloides_cryptus,
# Cypseloides_senex,
# Streptoprocne_phelpsi,
# Streptoprocne_rutila,
# Streptoprocne_zonaris,
# Streptoprocne_biscutata,
# Streptoprocne_semicollaris,
# Hydrochous_gigas,
# Collocalia_esculenta,
# Collocalia_linchi,
# Collocalia_troglodytes,
# Collocalia_elaphra,
# Collocalia_francica,
# Collocalia_unicolor,
# Collocalia_mearnsi,
# Collocalia_infuscata,
# Collocalia_hirundinacea,
# Collocalia_spodiopygia,
# Collocalia_terraereginae,
# Collocalia_brevirostris,
# Collocalia_whiteheadi,
# Collocalia_nuditarsus,
# Collocalia_orientalis,
# Collocalia_salangana,
# Collocalia_vanikorensis,
# Collocalia_pelewensis,
# Collocalia_inquieta,
# Collocalia_sawtelli,
# Collocalia_bartschi,
# Collocalia_leucophaea,
# Collocalia_maxima,
# Collocalia_fuciphaga,
# Collocalia_papuensis,
# Mearnsia_picina,
# Mearnsia_novaeguineae,
# Zoonavena_grandidieri,
# Zoonavena_thomensis,
# Zoonavena_sylvatica,
# Telacanthura_ussheri,
# Telacanthura_melanopygia,
# Rhaphidura_leucopygialis,
# Rhaphidura_sabini,
# Neafrapus_cassini,
# Neafrapus_boehmi,
# Hirundapus_caudacutus,
# Hirundapus_cochinchinensis,
# Hirundapus_giganteus,
# Hirundapus_celebensis,
# Chaetura_spinicaudus,
# Chaetura_egregia,
# Chaetura_martinica,
# Chaetura_cinereiventris,
# Chaetura_pelagica,
# Chaetura_vauxi,
# Chaetura_chapmani,
# Chaetura_brachyura,
# Schoutedenapus_myoptilus,
# Schoutedenapus_schoutedeni,
# Aeronautes_saxatalis,
# Aeronautes_montivagus,
# Aeronautes_andecolus,
# Tachornis_phoenicobia,
# Tachornis_furcata,
# Tachornis_squamata,
# Panyptila_sanctihieronymi,
# Panyptila_cayennensis,
# Cypsiurus_parvus,
# Cypsiurus_balasiensis,
# Tachymarptis_melba,
# Tachymarptis_aequatorialis,
# Apus_alexandri,
# Apus_apus,
# Apus_unicolor,
# Apus_niansae,
# Apus_pallidus,
# Apus_barbatus,
# Apus_berliozi,
# Apus_bradfieldi,
# Apus_pacificus,
# Apus_acuticauda,
# Apus_affinis,
# Apus_nipalensis,
# Apus_horus,
# Apus_caffer,
# Apus_batesi,
# Hemiprocne_coronata,
# Hemiprocne_longipennis,
# Hemiprocne_mystacea,
# Hemiprocne_comata,
# Glaucis_aeneus,
# Glaucis_hirsutus,
# Threnetes_niger,
# Threnetes_ruckeri,
# Phaethornis_yaruqui,
# Phaethornis_guy,
# Phaethornis_syrmatophorus,
# Phaethornis_superciliosus,
# Phaethornis_malaris,
# Phaethornis_eurynome,
# Phaethornis_hispidus,
# Phaethornis_anthophilus,
# Phaethornis_bourcieri,
# Phaethornis_koepckeae,
# Phaethornis_philippii,
# Phaethornis_squalidus,
# Phaethornis_rupurumii,
# Phaethornis_augusti,
# Phaethornis_pretrei,
# Phaethornis_subochraceus,
# Phaethornis_nattereri,
# Anopetia_gounellei,
# Phaethornis_ruber,
# Phaethornis_stuarti,
# Phaethornis_griseogularis,
# Phaethornis_longuemareus,
# Phaethornis_striigularis,
# Phaethornis_idaliae,
# Eutoxeres_aquila,
# Eutoxeres_condamini,
# Androdon_aequatorialis,
# Ramphodon_naevius,
# Glaucis_dohrnii,
# Doryfera_johannae,
# Doryfera_ludovicae,
# Phaeochroa_cuvierii,
# Campylopterus_curvipennis,
# Campylopterus_largipennis,
# Campylopterus_rufus,
# Campylopterus_hyperythrus,
# Campylopterus_duidae,
# Campylopterus_hemileucurus,
# Campylopterus_ensipennis,
# Campylopterus_falcatus,
# Campylopterus_phainopeplus,
# Campylopterus_villaviscensio,
# Eupetomena_macroura,
# Florisuga_mellivora,
# Florisuga_fusca,
# Colibri_delphinae,
# Colibri_thalassinus,
# Colibri_coruscans,
# Colibri_serrirostris,
# Anthracothorax_viridigula,
# Anthracothorax_prevostii,
# Anthracothorax_veraguensis,
# Anthracothorax_nigricollis,
# Anthracothorax_mango,
# Anthracothorax_dominicus,
# Anthracothorax_viridis,
# Avocettula_recurvirostris,
# Eulampis_jugularis,
# Eulampis_holosericeus,
# Chrysolampis_mosquitus,
# Orthorhyncus_cristatus,
# Klais_guimeti,
# Abeillia_abeillei,
# Stephanoxis_lalandi,
# Lophornis_ornatus,
# Lophornis_gouldii,
# Lophornis_magnificus,
# Lophornis_brachylophus,
# Lophornis_delattrei,
# Lophornis_stictolophus,
# Lophornis_chalybeus,
# Lophornis_pavoninus,
# Lophornis_helenae,
# Lophornis_adorabilis,
# Discosura_popelairii,
# Discosura_langsdorffi,
# Discosura_letitiae,
# Discosura_conversii,
# Discosura_longicaudus,
# Chlorestes_notata,
# Chlorostilbon_olivaresi,
# Chlorostilbon_mellisugus,
# Chlorostilbon_lucidus,
# Chlorostilbon_ricordii,
# Chlorostilbon_swainsonii,
# Chlorostilbon_maugaeus,
# Chlorostilbon_russatus,
# Chlorostilbon_stenurus,
# Chlorostilbon_alice,
# Chlorostilbon_poortmani,
# Cynanthus_sordidus,
# Cynanthus_latirostris,
# Cyanophaia_bicolor,
# Thalurania_ridgwayi,
# Thalurania_colombica,
# Thalurania_fannyi,
# Thalurania_furcata,
# Thalurania_watertonii,
# Thalurania_glaucopis,
# Panterpe_insignis,
# Damophila_julie,
# Lepidopyga_coeruleogularis,
# Lepidopyga_lilliae,
# Lepidopyga_goudoti,
# Hylocharis_xantusii,
# Hylocharis_leucotis,
# Hylocharis_eliciae,
# Hylocharis_sapphirina,
# Hylocharis_cyanus,
# Hylocharis_chrysura,
# Hylocharis_grayi,
# Chrysuronia_oenone,
# Goldmania_violiceps,
# Goethalsia_bella,
# Trochilus_polytmus,
# Leucochloris_albicollis,
# Polytmus_guainumbi,
# Polytmus_milleri,
# Polytmus_theresiae,
# Leucippus_fallax,
# Leucippus_baeri,
# Leucippus_taczanowskii,
# Leucippus_chlorocercus,
# Taphrospilus_hypostictus,
# Amazilia_viridicauda,
# Amazilia_chionogaster,
# Amazilia_candida,
# Amazilia_brevirostris,
# Amazilia_versicolor,
# Amazilia_luciae,
# Amazilia_fimbriata,
# Amazilia_lactea,
# Amazilia_amabilis,
# Amazilia_rosenbergi,
# Amazilia_boucardi,
# Amazilia_franciae,
# Amazilia_leucogaster,
# Amazilia_cyanocephala,
# Amazilia_cyanifrons,
# Amazilia_beryllina,
# Amazilia_cyanura,
# Amazilia_saucerrottei,
# Amazilia_tobaci,
# Amazilia_viridigaster,
# Amazilia_edward,
# Amazilia_rutila,
# Amazilia_yucatanensis,
# Amazilia_tzacatl,
# Amazilia_castaneiventris,
# Amazilia_amazilia,
# Amazilia_viridifrons,
# Amazilia_violiceps,
# Eupherusa_poliocerca,
# Eupherusa_cyanophrys,
# Eupherusa_eximia,
# Eupherusa_nigriventris,
# Elvira_chionura,
# Elvira_cupreiceps,
# Microchera_albocoronata,
# Chalybura_buffonii,
# Chalybura_urochrysia,
# Aphantochroa_cirrochloris,
# Lampornis_clemenciae,
# Lampornis_amethystinus,
# Lampornis_viridipallens,
# Lampornis_sybillae,
# Lampornis_hemileucus,
# Lampornis_castaneoventris,
# Lamprolaima_rhami,
# Adelomyia_melanogenys,
# Anthocephala_floriceps,
# Phlogophilus_hemileucurus,
# Phlogophilus_harterti,
# Clytolaema_rubricauda,
# Heliodoxa_imperatrix,
# Heliodoxa_xanthogonys,
# Heliodoxa_gularis,
# Heliodoxa_branickii,
# Heliodoxa_schreibersii,
# Heliodoxa_aurescens,
# Heliodoxa_rubinoides,
# Heliodoxa_jacula,
# Heliodoxa_leadbeateri,
# Eugenes_fulgens,
# Hylonympha_macrocerca,
# Sternoclyta_cyanopectus,
# Topaza_pella,
# Oreotrochilus_chimborazo,
# Oreotrochilus_estella,
# Oreotrochilus_leucopleurus,
# Oreotrochilus_melanogaster,
# Oreotrochilus_adela,
# Urochroa_bougueri,
# Patagona_gigas,
# Aglaeactis_cupripennis,
# Aglaeactis_castelnaudii,
# Aglaeactis_aliciae,
# Aglaeactis_pamela,
# Lafresnaya_lafresnayi,
# Pterophanes_cyanopterus,
# Coeligena_coeligena,
# Coeligena_wilsoni,
# Coeligena_prunellei,
# Coeligena_torquata,
# Coeligena_phalerata,
# Coeligena_bonapartei,
# Coeligena_helianthea,
# Coeligena_lutetiae,
# Coeligena_violifer,
# Coeligena_iris,
# Ensifera_ensifera,
# Sephanoides_sephaniodes,
# Sephanoides_fernandensis,
# Boissonneaua_flavescens,
# Boissonneaua_matthewsii,
# Boissonneaua_jardini,
# Heliangelus_mavors,
# Heliangelus_amethysticollis,
# Heliangelus_strophianus,
# Heliangelus_exortis,
# Heliangelus_viola,
# Heliangelus_regalis,
# Eriocnemis_nigrivestis,
# Eriocnemis_vestita,
# Eriocnemis_godini,
# Eriocnemis_luciani,
# Eriocnemis_cupreoventris,
# Eriocnemis_mosquera,
# Eriocnemis_glaucopoides,
# Eriocnemis_mirabilis,
# Eriocnemis_alinae,
# Eriocnemis_derbyi,
# Haplophaedia_aureliae,
# Haplophaedia_lugens,
# Urosticte_benjamini,
# Urosticte_ruficrissa,
# Ocreatus_underwoodii,
# Lesbia_victoriae,
# Lesbia_nuna,
# Sappho_sparganura,
# Polyonymus_caroli,
# Ramphomicron_microrhynchum,
# Ramphomicron_dorsale,
# Metallura_williami,
# Metallura_baroni,
# Metallura_odomae,
# Metallura_theresiae,
# Metallura_eupogon,
# Metallura_aeneocauda,
# Metallura_phoebe,
# Metallura_tyrianthina,
# Metallura_iracunda,
# Chalcostigma_ruficeps,
# Chalcostigma_olivaceum,
# Chalcostigma_stanleyi,
# Chalcostigma_heteropogon,
# Chalcostigma_herrani,
# Oxypogon_guerinii,
# Opisthoprora_euryptera,
# Taphrolesbia_griseiventris,
# Aglaiocercus_kingi,
# Aglaiocercus_berlepschi,
# Aglaiocercus_coelestis,
# Oreonympha_nobilis,
# Augastes_lumachella,
# Augastes_scutatus,
# Schistes_geoffroyi,
# Heliothryx_barroti,
# Heliothryx_auritus,
# Heliactin_bilophus,
# Loddigesia_mirabilis,
# Heliomaster_constantii,
# Heliomaster_longirostris,
# Heliomaster_squamosus,
# Heliomaster_furcifer,
# Rhodopis_vesper,
# Thaumastura_cora,
# Calliphlox_bryantae,
# Calliphlox_mitchellii,
# Doricha_enicura,
# Doricha_eliza,
# Tilmatura_dupontii,
# Microstilbon_burmeisteri,
# Calothorax_lucifer,
# Calothorax_pulcher,
# Archilochus_colubris,
# Archilochus_alexandri,
# Calypte_anna,
# Calypte_costae,
# Calliphlox_evelynae,
# Calliphlox_amethystina,
# Mellisuga_helenae,
# Mellisuga_minima,
# Stellula_calliope,
# Atthis_heloisa,
# Atthis_ellioti,
# Myrtis_fanny,
# Eulidia_yarrellii,
# Myrmia_micrura,
# Chaetocercus_mulsant,
# Chaetocercus_bombus,
# Chaetocercus_heliodor,
# Chaetocercus_astreans,
# Chaetocercus_berlepschi,
# Chaetocercus_jourdanii,
# Selasphorus_platycercus,
# Selasphorus_rufus,
# Selasphorus_sasin,
# Selasphorus_flammula,
# Selasphorus_scintilla,
# Selasphorus_ardens,
# Tauraco_persa,
# Tauraco_schuetti,
# Tauraco_schalowi,
# Tauraco_fischeri,
# Tauraco_livingstonii,
# Tauraco_corythaix,
# Tauraco_bannermani,
# Tauraco_erythrolophus,
# Tauraco_macrorhynchus,
# Tauraco_leucotis,
# Tauraco_ruspolii,
# Tauraco_hartlaubi,
# Tauraco_leucolophus,
# Ruwenzorornis_johnstoni,
# Tauraco_porphyreolophus,
# Musophaga_violacea,
# Musophaga_rossae,
# Corythaixoides_concolor,
# Corythaixoides_personatus,
# Corythaixoides_leucogaster,
# Crinifer_piscator,
# Corythaeola_cristata,
# Tyto_tenebricosa,
# Tyto_inexspectata,
# Tyto_nigrobrunnea,
# Tyto_sororcula,
# Tyto_manusi,
# Tyto_aurantia,
# Tyto_novaehollandiae,
# Tyto_rosenbergii,
# Tyto_soumagnei,
# Tyto_alba,
# Tyto_glaucops,
# Tyto_capensis,
# Tyto_longimembris,
# Phodilus_prigoginei,
# Phodilus_badius,
# Otus_sagittatus,
# Otus_rufescens,
# Otus_icterorhynchus,
# Otus_ireneae,
# Otus_balli,
# Otus_spilocephalus,
# Otus_umbra,
# Otus_angelinae,
# Otus_manadensis,
# Otus_longicornis,
# Otus_mindorensis,
# Otus_mirus,
# Otus_hartlaubi,
# Otus_brucei,
# Otus_flammeolus,
# Otus_scops,
# Otus_sunia,
# Otus_senegalensis,
# Otus_elegans,
# Otus_mantananensis,
# Otus_magicus,
# Otus_beccarii,
# Otus_alfredi,
# Otus_enganensis,
# Otus_insularis,
# Otus_rutilus,
# Otus_pembaensis,
# Otus_capnodes,
# Otus_pauliani,
# Otus_brookii,
# Otus_bakkamoena,
# Otus_lettia,
# Otus_lempiji,
# Otus_semitorques,
# Otus_mentawi,
# Otus_fuliginosus,
# Otus_megalotis,
# Otus_silvicola,
# Otus_leucotis,
# Megascops_kennicottii,
# Megascops_seductus,
# Megascops_cooperi,
# Megascops_asio,
# Megascops_trichopsis,
# Megascops_choliba,
# Megascops_koepckeae,
# Megascops_roboratus,
# Megascops_clarkii,
# Megascops_barbarus,
# Megascops_ingens,
# Megascops_marshalli,
# Megascops_watsonii,
# Megascops_atricapilla,
# Megascops_hoyi,
# Megascops_guatemalae,
# Megascops_sanctaecatarinae,
# Gymnoglaux_lawrencii,
# Megascops_nudipes,
# Otus_podarginus,
# Megascops_albogularis,
# Mimizuku_gurneyi,
# Bubo_virginianus,
# Bubo_bubo,
# Bubo_bengalensis,
# Bubo_ascalaphus,
# Bubo_capensis,
# Bubo_africanus,
# Bubo_poensis,
# Bubo_vosseleri,
# Bubo_nipalensis,
# Bubo_sumatranus,
# Bubo_shelleyi,
# Bubo_lacteus,
# Bubo_coromandus,
# Bubo_leucostictus,
# Bubo_philippensis,
# Ketupa_blakistoni,
# Ketupa_zeylonensis,
# Ketupa_flavipes,
# Ketupa_ketupu,
# Bubo_scandiaca,
# Scotopelia_peli,
# Scotopelia_ussheri,
# Scotopelia_bouvieri,
# Strix_seloputo,
# Strix_ocellata,
# Strix_leptogrammica,
# Strix_aluco,
# Strix_butleri,
# Strix_occidentalis,
# Strix_varia,
# Strix_fulvescens,
# Strix_hylophila,
# Strix_rufipes,
# Strix_uralensis,
# Strix_davidi,
# Strix_nebulosa,
# Strix_virgata,
# Strix_nigrolineata,
# Strix_huhula,
# Strix_albitarsis,
# Strix_woodfordii,
# Jubula_lettii,
# Lophostrix_cristata,
# Pulsatrix_perspicillata,
# Pulsatrix_koeniswaldiana,
# Pulsatrix_melanota,
# Surnia_ulula,
# Glaucidium_passerinum,
# Glaucidium_brodiei,
# Glaucidium_perlatum,
# Glaucidium_californicum,
# Glaucidium_gnoma,
# Glaucidium_jardinii,
# Glaucidium_bolivianum,
# Glaucidium_palmarum,
# Glaucidium_sanchezi,
# Glaucidium_griseiceps,
# Glaucidium_parkeri,
# Glaucidium_hardyi,
# Glaucidium_minutissimum,
# Glaucidium_brasilianum,
# Glaucidium_peruanum,
# Glaucidium_nanum,
# Glaucidium_siju,
# Glaucidium_tephronotum,
# Glaucidium_sjostedti,
# Glaucidium_cuculoides,
# Glaucidium_castanopterum,
# Glaucidium_radiatum,
# Glaucidium_castanonotum,
# Glaucidium_capense,
# Glaucidium_castaneum,
# Glaucidium_albertinum,
# Xenoglaux_loweryi,
# Micrathene_whitneyi,
# Athene_noctua,
# Athene_brama,
# Heteroglaux_blewitti,
# Athene_cunicularia,
# Aegolius_funereus,
# Aegolius_acadicus,
# Aegolius_ridgwayi,
# Aegolius_harrisii,
# Ninox_rufa,
# Ninox_strenua,
# Ninox_connivens,
# Ninox_rudolfi,
# Ninox_boobook,
# Ninox_novaeseelandiae,
# Ninox_scutulata,
# Ninox_affinis,
# Ninox_superciliaris,
# Ninox_philippensis,
# Ninox_ochracea,
# Ninox_squamipila,
# Ninox_natalis,
# Ninox_theomacha,
# Ninox_meeki,
# Ninox_punctulata,
# Ninox_variegata,
# Ninox_odiosa,
# Ninox_jacquinoti,
# Uroglaux_dimorpha,
# Pseudoscops_grammicus,
# Asio_stygius,
# Asio_otus,
# Asio_abyssinicus,
# Asio_madagascariensis,
# Pseudoscops_clamator,
# Asio_flammeus,
# Asio_capensis,
# Nesasio_solomonensis,
# Aegotheles_crinifrons,
# Aegotheles_insignis,
# Aegotheles_cristatus,
# Aegotheles_savesi,
# Aegotheles_bennettii,
# Aegotheles_wallacii,
# Aegotheles_archboldi,
# Aegotheles_albertisi,
# Podargus_strigoides,
# Podargus_papuensis,
# Podargus_ocellatus,
# Batrachostomus_auritus,
# Batrachostomus_harterti,
# Batrachostomus_septimus,
# Batrachostomus_stellatus,
# Batrachostomus_moniliger,
# Batrachostomus_hodgsoni,
# Batrachostomus_poliolophus,
# Batrachostomus_javensis,
# Batrachostomus_cornutus,
# Steatornis_caripensis,
# Nyctibius_grandis,
# Nyctibius_aethereus,
# Nyctibius_jamaicensis,
# Nyctibius_griseus,
# Nyctibius_maculosus,
# Nyctibius_leucopterus,
# Nyctibius_bracteatus,
# Eurostopodus_argus,
# Eurostopodus_mystacalis,
# Eurostopodus_diabolicus,
# Eurostopodus_papuensis,
# Eurostopodus_archboldi,
# Eurostopodus_temminckii,
# Eurostopodus_macrotis,
# Lurocalis_semitorquatus,
# Lurocalis_rufiventris,
# Chordeiles_pusillus,
# Nyctiprogne_vielliardi,
# Chordeiles_rupestris,
# Chordeiles_acutipennis,
# Chordeiles_minor,
# Chordeiles_gundlachii,
# Nyctiprogne_leucopyga,
# Podager_nacunda,
# Nyctidromus_albicollis,
# Phalaenoptilus_nuttallii,
# Siphonorhis_brewsteri,
# Nyctiphrynus_mcleodii,
# Nyctiphrynus_yucatanicus,
# Nyctiphrynus_ocellatus,
# Nyctiphrynus_rosenbergi,
# Caprimulgus_carolinensis,
# Caprimulgus_rufus,
# Caprimulgus_cubanensis,
# Caprimulgus_salvini,
# Caprimulgus_badius,
# Caprimulgus_sericocaudatus,
# Caprimulgus_ridgwayi,
# Caprimulgus_vociferus,
# Caprimulgus_noctitherus,
# Caprimulgus_saturatus,
# Caprimulgus_longirostris,
# Caprimulgus_cayennensis,
# Eleothreptus_candicans,
# Caprimulgus_maculicaudus,
# Caprimulgus_parvulus,
# Caprimulgus_anthonyi,
# ...
# Saltatricula_multicolor,
# Coryphospingus_pileatus,
# Coryphospingus_cucullatus,
# Rhodospingus_cruentus,
# Phrygilus_atriceps,
# Phrygilus_punensis,
# Phrygilus_gayi,
# Phrygilus_patagonicus,
# Phrygilus_fruticeti,
# Phrygilus_unicolor,
# Phrygilus_dorsalis,
# Phrygilus_erythronotus,
# Phrygilus_plebejus,
# Phrygilus_carbonarius,
# Phrygilus_alaudinus,
# Melanodera_melanodera,
# Melanodera_xanthogramma,
# Haplospiza_rustica,
# Haplospiza_unicolor,
# Acanthidops_bairdii,
# Lophospingus_pusillus,
# Lophospingus_griseocristatus,
# Donacospiza_albifrons,
# Rowettia_goughensis,
# Nesospiza_acunhae,
# Nesospiza_wilkinsi,
# Diuca_speculifera,
# Diuca_diuca,
# Idiopsar_brachyurus,
# Piezorhina_cinerea,
# Xenospingus_concolor,
# Incaspiza_pulchra,
# Incaspiza_personata,
# Incaspiza_ortizi,
# Incaspiza_laeta,
# Incaspiza_watkinsi,
# Poospiza_thoracica,
# Poospiza_boliviana,
# Poospiza_alticola,
# Poospiza_hypochondria,
# Poospiza_ornata,
# Poospiza_erythrophrys,
# Poospiza_whitii,
# Poospiza_nigrorufa,
# Poospiza_lateralis,
# Poospiza_rubecula,
# Compsospiza_garleppi,
# Compsospiza_baeri,
# Poospiza_caesar,
# Poospiza_hispaniolensis,
# Poospiza_torquata,
# Poospiza_melanoleuca,
# Poospiza_cinerea,
# Sicalis_citrina,
# Sicalis_lutea,
# Sicalis_uropygialis,
# Sicalis_luteocephala,
# Sicalis_auriventris,
# Sicalis_olivascens,
# Sicalis_lebruni,
# Sicalis_columbiana,
# Sicalis_flaveola,
# Sicalis_luteola,
# Sicalis_raimondii,
# Sicalis_taczanowskii,
# Emberizoides_herbicola,
# Emberizoides_duidae,
# Emberizoides_ypiranganus,
# Embernagra_platensis,
# Embernagra_longicauda,
# Volatinia_jacarina,
# Sporophila_frontalis,
# Sporophila_falcirostris,
# Sporophila_schistacea,
# Sporophila_intermedia,
# Sporophila_plumbea,
# Sporophila_corvina,
# Sporophila_americana,
# Sporophila_murallae,
# Sporophila_torqueola,
# Sporophila_collaris,
# Sporophila_bouvronides,
# Sporophila_lineola,
# Sporophila_luctuosa,
# Sporophila_nigricollis,
# Sporophila_melanops,
# Sporophila_caerulescens,
# Sporophila_albogularis,
# Sporophila_leucoptera,
# Sporophila_peruviana,
# Sporophila_simplex,
# Sporophila_nigrorufa,
# Sporophila_bouvreuil,
# Sporophila_minuta,
# Sporophila_hypoxantha,
# Sporophila_ruficollis,
# Sporophila_palustris,
# Sporophila_castaneiventris,
# Sporophila_hypochroma,
# Sporophila_cinnamomea,
# Sporophila_melanogaster,
# Sporophila_telasco,
# Oryzoborus_nuttingi,
# Oryzoborus_crassirostris,
# Oryzoborus_atrirostris,
# Oryzoborus_maximiliani,
# Oryzoborus_angolensis,
# Amaurospiza_concolor,
# Amaurospiza_moesta,
# Melopyrrha_nigra,
# Dolospingus_fringilloides,
# Catamenia_analis,
# Catamenia_inornata,
# Catamenia_homochroa,
# Tiaris_obscurus,
# Tiaris_canorus,
# Tiaris_olivaceus,
# Tiaris_bicolor,
# Tiaris_fuliginosus,
# Loxipasser_anoxanthus,
# Loxigilla_portoricensis,
# Loxigilla_violacea,
# Loxigilla_noctis,
# Diglossa_baritula,
# Diglossa_plumbea,
# Diglossa_sittoides,
# Diglossa_venezuelensis,
# Diglossa_albilatera,
# Diglossa_gloriosissima,
# Diglossa_lafresnayii,
# Diglossa_mystacalis,
# Diglossa_gloriosa,
# Diglossa_humeralis,
# Diglossa_brunneiventris,
# Diglossa_carbonaria,
# Diglossa_duidae,
# Diglossa_major,
# Diglossa_indigotica,
# Diglossa_glauca,
# Diglossa_caerulescens,
# Diglossa_cyanea,
# Euneornis_campestris,
# Melanospiza_richardsoni,
# Geospiza_magnirostris,
# Geospiza_fortis,
# Geospiza_fuliginosa,
# Geospiza_difficilis,
# Geospiza_scandens,
# Geospiza_conirostris,
# Platyspiza_crassirostris,
# Camarhynchus_psittacula,
# Camarhynchus_pauper,
# Camarhynchus_parvulus,
# Camarhynchus_pallidus,
# Camarhynchus_heliobates,
# Certhidea_olivacea,
# Pinaroloxias_inornata,
# Spiza_americana,
# Pheucticus_chrysopeplus,
# Pheucticus_chrysogaster,
# Pheucticus_tibialis,
# Pheucticus_aureoventris,
# Pheucticus_ludovicianus,
# Pheucticus_melanocephalus,
# Cardinalis_cardinalis,
# Cardinalis_phoeniceus,
# Cardinalis_sinuatus,
# Caryothraustes_poliogaster,
# Caryothraustes_canadensis,
# Parkerthraustes_humeralis,
# Rhodothraupis_celaeno,
# Periporphyrus_erythromelas,
# Saltator_grossus,
# Saltator_fuliginosus,
# Saltator_atriceps,
# Saltator_maximus,
# Saltator_atripennis,
# Saltator_coerulescens,
# Saltator_similis,
# Saltator_orenocensis,
# Saltator_nigriceps,
# Saltator_aurantiirostris,
# Saltator_maxillosus,
# Saltator_cinctus,
# Saltator_atricollis,
# Saltator_rufiventris,
# Saltator_albicollis,
# Saltator_striatipectus,
# Cyanoloxia_glaucocaerulea,
# Cyanocompsa_cyanoides,
# Cyanocompsa_parellina,
# Cyanocompsa_brissonii,
# Passerina_caerulea,
# Passerina_amoena,
# Passerina_cyanea,
# Passerina_versicolor,
# Passerina_ciris,
# Passerina_rositae,
# Passerina_leclancherii,
# Porphyrospiza_caerulescens,
# Clypicterus_oseryi,
# Psarocolius_decumanus,
# Psarocolius_viridis,
# Psarocolius_atrovirens,
# Psarocolius_angustifrons,
# Psarocolius_wagleri,
# Ocyalus_latirostris,
# Psarocolius_montezuma,
# Psarocolius_cassini,
# Psarocolius_bifasciatus,
# Psarocolius_guatimozinus,
# Cacicus_cela,
# Cacicus_haemorrhous,
# Cacicus_uropygialis,
# Cacicus_koepckeae,
# Cacicus_chrysopterus,
# Cacicus_chrysonotus,
# Cacicus_sclateri,
# Cacicus_solitarius,
# Cacicus_melanicterus,
# Amblycercus_holosericeus,
# Icterus_cayanensis,
# Icterus_graduacauda,
# Icterus_chrysater,
# Icterus_nigrogularis,
# Icterus_leucopteryx,
# Icterus_auratus,
# Icterus_mesomelas,
# Icterus_auricapillus,
# Icterus_graceannae,
# Icterus_pectoralis,
# Icterus_gularis,
# Icterus_pustulatus,
# Icterus_icterus,
# Icterus_jamacaii,
# Icterus_galbula,
# Icterus_bullockii,
# Icterus_abeillei,
# Icterus_cucullatus,
# Icterus_spurius,
# Icterus_wagleri,
# Icterus_dominicensis,
# Icterus_oberi,
# Icterus_bonana,
# Icterus_laudabilis,
# Icterus_maculialatus,
# Icterus_parisorum,
# Nesopsar_nigerrimus,
# Gymnomystax_mexicanus,
# Xanthocephalus_xanthocephalus,
# Xanthopsar_flavus,
# Agelasticus_xanthophthalmus,
# Agelasticus_thilius,
# Agelasticus_cyanopus,
# Agelaius_phoeniceus,
# Agelaius_assimilis,
# Agelaius_tricolor,
# Chrysomus_icterocephalus,
# Agelaius_humeralis,
# Agelaius_xanthomus,
# Chrysomus_ruficapillus,
# Sturnella_militaris,
# Sturnella_superciliaris,
# Sturnella_bellicosa,
# Sturnella_defilippii,
# Sturnella_loyca,
# Sturnella_magna,
# Sturnella_neglecta,
# Pseudoleistes_guirahuro,
# Pseudoleistes_virescens,
# Amblyramphus_holosericeus,
# Hypopyrrhus_pyrohypogaster,
# Curaeus_curaeus,
# Curaeus_forbesi,
# Gnorimopsar_chopi,
# Oreopsar_bolivianus,
# Lampropsar_tanagrinus,
# Macroagelaius_imthurni,
# Macroagelaius_subalaris,
# Dives_atroviolaceus,
# Dives_dives,
# Dives_warszewiczi,
# Quiscalus_mexicanus,
# Quiscalus_major,
# Quiscalus_nicaraguensis,
# Quiscalus_quiscula,
# Quiscalus_niger,
# Quiscalus_lugubris,
# Euphagus_carolinus,
# Euphagus_cyanocephalus,
# Agelaioides_badius,
# Molothrus_rufoaxillaris,
# Molothrus_bonariensis,
# Molothrus_aeneus,
# Molothrus_ater,
# Molothrus_oryzivorus,
# Dolichonyx_oryzivorus,
# Circaetus_beaudouini,
# Accipiter_toussenelii,
# Colinus_leucopogon,
# Larus_thayeri,
# Procelsterna_albivitta,
# Loriculus_sclateri,
# Cyanoramphus_forbesi,
# Cyanoramphus_malherbi,
# Surniculus_velutinus,
# Cuculus_optatus,
# Bubo_cinerascens,
# Glaucidium_nubicola,
# Ptilopsis_granti,
# Strix_chacoensis,
# Bubo_magellanicus,
# Otus_moheliensis,
# Glaucidium_costaricanum,
# Megascops_colombianus,
# Otus_alius,
# Megascops_petersoni,
# Otus_collari,
# Aegotheles_tatei,
# Caprimulgus_ekmani,
# Caprimulgus_ruwenzorii,
# Caprimulgus_nigriscapularis,
# Phaethornis_longirostris,
# Haplophaedia_assimilis,
# Trochilus_scitulus,
# Phaethornis_atrimentalis,
# Heliangelus_micraster,
# Apalharpactes_mackloti,
# Capito_wallacei,
# Picumnus_nigropunctatus,
# Dendropicos_lugubris,
# Campethera_scriptoricauda,
# Phasianus_versicolor,
# Poecilotriccus_luluae,
# Hemitriccus_griseipectus,
# Zimmerius_flavidifrons,
# Phaeomyias_tumbezana,
# Suiriri_islerorum,
# Myiopagis_olallai,
# Inezia_caudata,
# Phylloscartes_parkeri,
# Tolmomyias_traylori,
# Tolmomyias_flavotectus,
# Tolmomyias_viridiceps,
# Onychorhynchus_mexicanus,
# Myiobius_sulphureipygius,
# Contopus_punensis,
# Ochthoeca_nigrita,
# Ochthoeca_thoracica,
# Muscisaxicola_griseus,
# Knipolegus_franciscanus,
# Sirystes_albogriseus,
# Laniisoma_buckleyi,
# Thamnophilus_ambiguus,
# Thamnophilus_pelzelni,
# Thamnophilus_stictocephalus,
# Thamnophilus_sticturus,
# Myrmotherula_ignota,
# Myrmotherula_multostriata,
# Myrmotherula_pacifica,
# Epinecrophylla_fjeldsaai,
# Myrmotherula_luctuosa,
# Herpsilochmus_sellowi,
# Herpsilochmus_gentryi,
# Formicivora_intermedia,
# Cercomacra_laeta,
# Cercomacra_parkeri,
# Furnarius_cinnamomeus,
# Furnarius_longirostris,
# Cranioleuca_vulpecula,
# Acrobatornis_fonsecai,
# Phacellodomus_inornatus,
# Pseudoseisura_unirufa,
# Hyloctistes_virgatus,
# Dendrocolaptes_sanctithomae,
# Lepidocolaptes_falcinellus,
# Hylopezus_auricularis,
# Conopophaga_cearae,
# Scytalopus_latrans,
# Scytalopus_iraiensis,
# Pica_hudsonia,
# Corvus_minutus,
# Turdus_daguae,
# Progne_elegans,
# Progne_murphyi,
# Melozone_cabanisi,
# Arremon_franciscanus,
# Arremon_semitorquatus,
# Atlapetes_latinuchus,
# Atlapetes_melanolaemus,
# Atlapetes_melanopsis,
# Atlapetes_canigenis,
# Atlapetes_forbesi,
# Dendroica_aestiva,
# Dendroica_delicata,
# Dendroica_subita,
# Hemispingus_auricularis,
# Hemispingus_ochraceus,
# Hemispingus_piurae,
# Calyptophilus_tertius,
# Piranga_hepatica,
# Piranga_lutea,
# Ramphocelus_costaricensis,
# Ramphocelus_icteronotus,
# Spindalis_dominicensis,
# Spindalis_nigricephala,
# Spindalis_portoricensis,
# Cacicus_microrhynchus,
# Cacicus_leucoramphus,
# Icterus_croconotus,
# Icterus_prosthemelas,
# Molothrus_armenti,
# Nectarinia_tsavoensis,
# Laniarius_brauni,
# Laniarius_amboimensis,
# Prionops_rufiventris,
# Onychognathus_neumanni,
# Passer_shelleyi,
# Passer_cordofanicus,
# Parmoptila_jamesoni,
# Lagonosticta_nitidula,
# Lagonosticta_sanguinodorsalis,
# Ortygospiza_fuscocrissa,
# Serinus_whytii,
# Serinus_flavivertex,
# Emberiza_vincenti,
# Liocichla_bugunorum,
# Lipaugus_weberi,
# Micrastur_mintoni,
# Thamnophilus_divisorius,
# Motacilla_samveasnae,
# Ninox_burhani,
# Scolopax_bukidnonensis,
# Otus_thilohoffmanni,
# Ninox_sumbaensis,
# Percnostola_arenarum,
# Polioptila_clementsi,
# Scytalopus_pachecoi,
# Sheppardia_aurantiithorax,
# Scytalopus_stilesi,
# Scytalopus_rodriguezi,
# Ninox_ios,
# Hypositta_perdita,
# Gallirallus_calayanensis,
# Aethopyga_linaraborae,
# Amaurornis_magnirostris,
# Amaurospiza_carrizalensis,
# Antilophia_bokermanni,
# Atlapetes_terborghi,
# Bradypterus_alishanensis,
# Garrulax_ngoclinhensis,
# Caprimulgus_solala,
# Henicorhina_negreti,
# Zimmerius_villarejoi,
# Cettia_haddeni,
# Actinodura_sodangorum,
# Garrulax_konkakinhensis,
# Glaucidium_mooreorum,
# Grallaria_ridgelyi,
# Gymnocrex_talaudensis,
# Calicalicus_rufocarpalis,
# Heinrichia_calligyna,
# Sporophila_ardesiaca,
# Cnipodectes_superrufus,
# Eriocnemis_isabellae,
# Phyllomyias_weedeni,
# Pycnonotus_hualon,
# Stachyris_nonggangensis,
# Oceanites_maorianus,
# Rhynchotus_maculicollis,
# Megapodius_tenimberensis,
# Megapodius_geelvinkianus,
# Arborophila_campbelli,
# Arborophila_sumatrana,
# Arborophila_rolli,
# Lophura_hatinhensis,
# Lophura_hoogerwerfi,
# Crossoptilon_harmani,
# Polyplectron_katsumatae,
# Centrocercus_minimus,
# Branta_hutchinsii,
# Anas_wyvilliana,
# Anas_laysanensis,
# Anas_fulvigula,
# Anas_gracilis,
# Anas_nesiotis,
# Anas_chlorotis,
# Anas_andium,
# Anas_puna,
# Melanerpes_pulcher,
# Dendrocopos_ramsayi,
# Dendrocopos_nanus,
# Picoides_arizonae,
# Celeus_obrieni,
# Picus_vaillantii,
# Megalaima_faber,
# Megalaima_nuchalis,
# Pogoniulus_makawai,
# Trachyphonus_usambiro,
# Capito_auratus,
# Notharchus_hyperrhynchus,
# Tockus_jacksoni,
# Bycanistes_albotibialis,
# Trogon_mesurus,
# Trogon_chionurus,
# Trogon_caligatus,
# Todiramphus_ruficollaris,
# Ceyx_rufidorsa,
# Merops_nubicoides,
# Cuculus_lepidus,
# Cacomantis_passerinus,
# Cacomantis_sepulcralis,
# Chrysococcyx_russatus,
# Chrysococcyx_crassirostris,
# Eudynamys_melanorhynchus,
# Neomorphus_squamiger,
# Cyanoramphus_saisseti,
# Cyanoramphus_cookii,
# Eunymphicus_uvaeensis,
# Pyrrhura_griseipectus,
# Pyrrhura_pfrimeri,
# Amazona_auropalliata,
# Collocalia_rogersi,
# Collocalia_vulcanorum,
# Collocalia_palawanensis,
# Collocalia_amelis,
# Collocalia_ocista,
# Collocalia_germani,
# Chaetura_fumosa,
# Chaetura_viridipennis,
# Chaetura_meridionalis,
# Apus_sladeniae,
# Apus_balstoni,
# Apus_toulsoni,
# Threnetes_leucurus,
# Campylopterus_excellens,
# Chlorostilbon_auriceps,
# Chlorostilbon_forficatus,
# Chlorostilbon_assimilis,
# Chlorostilbon_canivetii,
# Chlorostilbon_gibsoni,
# Chlorostilbon_melanorhynchus,
# Hylocharis_humboldtii,
# Lampornis_calolaemus,
# Topaza_pyra,
# Coeligena_orina,
# Otus_mayottensis,
# Rigidipenna_inexpectata,
# Batrachostomus_mixtus,
# Batrachostomus_affinis,
# Caprimulgus_meesi,
# Laterallus_tuerosi,
# Scolopax_rosenbergii,
# Gallinago_andina,
# Rostratula_australis,
# Haematopus_finschi,
# Himantopus_leucocephalus,
# Himantopus_mexicanus,
# Cursorius_somalensis,
# Catharacta_lonnbergi,
# Larus_michahellis,
# Brachyramphus_perdix,
# Chondrohierax_wilsonii,
# Gyps_tenuirostris,
# Circus_macrosceles,
# Buteogallus_gundlachii,
# Aquila_hastata,
# Nisaetus_floris,
# Falco_pelegrinoides,
# Sula_granti,
# Anhinga_rufa,
# Egretta_gularis,
# Phoenicopterus_roseus,
# Bostrychia_bocagei,
# Gavia_pacifica,
# Pseudobulweria_becki,
# Pterodroma_brevipes,
# Pterodroma_heraldica,
# Pterodroma_atrata,
# Pterodroma_sandwichensis,
# Pterodroma_caribbaea,
# Procellaria_conspicillata,
# Calonectris_edwardsii,
# Puffinus_mauretanicus,
# Puffinus_newelli,
# Diomedea_antipodensis,
# Diomedea_dabbenena,
# Diomedea_sanfordi,
# Thalassarche_impavida,
# Thalassarche_steadi,
# Thalassarche_eremita,
# Thalassarche_salvini,
# Oceanodroma_monteiroi,
# Zimmerius_acer,
# Zimmerius_albigularis,
# Corapipo_altera,
# Hypocnemis_ochrogyna,
# Hypocnemis_subflava,
# Hypocnemis_peruviana,
# Hypocnemis_flavescens,
# Hypocnemis_striata,
# Schistocichla_humaythae,
# Schistocichla_rufifacies,
# Schistocichla_saturata,
# Schistocichla_brunneiceps,
# Myrmeciza_castanea,
# Upucerthia_saturatior,
# Cinclodes_albiventris,
# Cinclodes_albidiventris,
# Phacellodomus_ferrugineigula,
# Amytornis_merrotsyi,
# Amytornis_ballarae,
# Anthochaera_lunulata,
# Acanthiza_apicalis,
# Poecilodryas_cerviniventris,
# Chloropsis_jerdoni,
# Chloropsis_kinabaluensis,
# Chloropsis_media,
# Orthonyx_novaeguineae,
# Lanius_marwitzi,
# Colluricincla_sanghirensis,
# Corvus_levaillantii,
# Corvus_edithae,
# Clytorhynchus_sanctaecrucis,
# Telophorus_quadricolor,
# Batis_crypta,
# Batis_occulta,
# Platysteira_laticincta,
# Platysteira_chalybea,
# Platysteira_jamesoni,
# Chaetops_aurantius,
# Monticola_erythronotus,
# Myophonus_castaneus,
# Myophonus_borneensis,
# Zoothera_joiceyi,
# Zoothera_leucolaema,
# Zoothera_mendeni,
# Zoothera_tanganjicae,
# Zoothera_imbricata,
# Zoothera_turipavae,
# Myiomela_albiventris,
# Dioptrornis_fischeri,
# Ficedula_albicilla,
# Cyornis_magnirostris,
# Oenanthe_chrysopygia,
# Lamprotornis_elisabeth,
# Certhia_hodgsoni,
# Certhia_tianquanensis,
# Certhia_manipurensis,
# Remiz_macronyx,
# Parus_hypermelaenus,
# Regulus_madeirensis,
# Andropadus_nigriceps,
# Bleda_notatus,
# Cisticola_discolor,
# Prinia_hypoxantha,
# Apalis_fuscigularis,
# Apalis_lynesi,
# Apalis_flavigularis,
# Apalis_argentea,
# Zosterops_nehrkorni,
# Zosterops_stalkeri,
# Cettia_brunnescens,
# Bradypterus_bangwaensis,
# Bradypterus_davidi,
# Bradypterus_montis,
# Bradypterus_mandelli,
# Bradypterus_timorensis,
# Nesillas_lantzii,
# Acrocephalus_orinus,
# Hippolais_opaca,
# Phylloscopus_ibericus,
# Phylloscopus_canariensis,
# Phylloscopus_yunnanensis,
# Phylloscopus_forresti,
# Phylloscopus_claudiae,
# Phylloscopus_goodsoni,
# Phylloscopus_ogilviegranti,
# Seicercus_tephrocephalus,
# Seicercus_soror,
# Seicercus_whistleri,
# Seicercus_omeiensis,
# Seicercus_valentini,
# Hyliota_usambara,
# Garrulax_ruficeps,
# Garrulax_bicolor,
# Garrulax_ferrarius,
# Garrulax_castanotis,
# Garrulax_courtoisi,
# Garrulax_berthemyi,
# Garrulax_annamensis,
# Garrulax_taewanus,
# Strophocincla_fairbanki,
# Garrulax_imbricatus,
# Garrulax_peninsulae,
# Garrulax_chrysopterus,
# Garrulax_melanostigma,
# Trichastoma_buettikoferi,
# Pomatorhinus_swinhoei,
# Pomatorhinus_mcclellandi,
# Pomatorhinus_gravivox,
# Pomatorhinus_melanurus,
# Pomatorhinus_musicus,
# Rimator_pasquieri,
# Rimator_albostriatus,
# Robsonius_sorsogonensis,
# Pnoepyga_formosana,
# Spelaeornis_kinneari,
# Spelaeornis_reptatus,
# Spelaeornis_oatesi,
# Sphenocichla_roberti,
# Stachyris_pygmaea,
# Macronous_bornensis,
# Micromacronus_sordidus,
# Cutia_legalleni,
# Gampsorhynchus_torquatus,
# Alcippe_klossi,
# Alcippe_danisi,
# Alcippe_manipurensis,
# Alcippe_formosana,
# Alcippe_grotei,
# Heterophasia_desgodinsi,
# Yuhina_torqueola,
# Paradoxornis_margaritae,
# Mirafra_alopex,
# Mirafra_affinis,
# Mirafra_microptera,
# Mirafra_erythrocephala,
# Certhilauda_subcoronata,
# Certhilauda_semitorquata,
# Certhilauda_barlowi,
# Nectarinia_fuelleborni,
# Aethopyga_bella,
# Passer_hemileucus,
# Lagonosticta_landanae,
# Lonchura_nigriceps,
# Lonchura_atricapilla,
# Carduelis_corsicana,
# Rhynchostruthus_percivali,
# Rhynchostruthus_louisae,
# Loxia_megaplaga,
# Nesospiza_questi,
# Poospiza_cabanisi,
# Oryzoborus_funereus,
# Loxigilla_barbadensis,
# Eurochelidon_sirintarae,
# Leucosticte_sillemi,
# Zosterops_gibbsi,
# Zosterops_somadikartai,
# Hirundo_perdita,
# Amazilia_decora,
